# %%
import numpy as np
import matplotlib.pyplot as plt

n = 2 # 미니배치 크기
h = 3 # 은닉 상태 벡터의 차원 수
t = 20 # 시계열 데이터의 길이

dh = np.ones((n, h))
np.random.seed(3)
wh = np.random.randn(h, h)

norm_list = []
for t in range(t):
    dh = np.matmul(dh, wh.T)
    norm = np.sqrt(np.sum(dh**2)) / n
    norm_list.append(norm)

# %%
plt.plot(range(len(norm_list)), norm_list)
plt.show()

# %%
dh = np.ones((n, h))
np.random.seed(3)
wh = np.random.randn(h, h) * 0.5

norm_list = []
for t in range(t):
    dh = np.matmul(dh, wh.T)
    norm = np.sqrt(np.sum(dh**2)) / n
    norm_list.append(norm)

# %%
plt.plot(range(len(norm_list)), norm_list)
plt.show()

# %%
dw1 = np.random.rand(3, 3) * 10
dw2 = np.random.rand(3, 3) * 10
grads = [dw1, dw2]
max_norm = 5.0

def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad**2)
    total_norm = np.sqrt(total_norm)
    
    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate

# %%
class LSTM:
    def __init__(self, wx, wh, b):
        self.params = [wx, wh, b]
        self.grads = [np.zeros_like(wx), np.zeros_like(wh), np.zeros_like(b)]
        self.cache = None
    
    def forward(self, x, h_prev, c_prev):
        wx, wh, b = self.params
        n, h = h_prev.shape
        
        a = np.matmul(x, wx) + np.matmul(h_prev, wh) + b
        
        # slice
        f = a[:, :h]
        g = a[:, h:2*h]
        i = a[:, 2*h:3*h]
        o = a[:, 3*h:4*h]
        
        f = sigmoid(f)
        g = np.tanh(g)
        i = sigmoid(i)
        o = sigmoid(o)
        
        c_next = f * c_prev + g * i
        h_next = o * np.tanh(c_next)
        
        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next

# %%
class TimeLSTM:
    def __init__(self, wx, wh, b, stateful=False):
        self.params = [wx, wh, b]
        self.grads = [np.zeros_like(wx), np.zeros_like(wh), np.zeros_like(b)]
        self.layers = None
        self.h, self.c = None, None
        self.dh = None
        self.stateful = stateful
        
    def forward(self, xs):
        wx, wh, b = self.params
        n, t, d = xs.shape
        h = wh.shape[0]
        
        self.layers = []
        hs = np.empty((n, t, h), dtype='f')
        
        if not self.stateful or self.h in None:
            self.h = np.zeros((n, h), dtype='f')
        if not self.stateful or self.c in None:
            self.c = np.zeros((n, h), dtype='f')
            
        for t in range(t):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
            hs[:, t, :] = self.h
            
            self.layers.append(layer)
            
        return hs
    
    def backward(self, dhs):
        wx, wh, b = self.params
        n, t, h = dhs.shape
        d = wx.shape[0]
        
        dxs = np.empty((n, t, d), dtype='f')
        dh, dc = 0, 0
        
        grads = [0,0,0]
        for t in reversed(range(t)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
                
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
            
        self.dh = dh
        return dxs
    
    def set_state(self, h, c=None):
        self.h, self.c = h, c
        
    def reset_state(self):
        self.h, self.c = None, None

# %%
import sys
sys.path.append('..')
from common.time_layers import *
import pickle

class Rnnlm:
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        v, d, h = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        # 가중치 초기화
        embed_w = (rn(v, d) / 100).astype('f')
        lstm_wx = (rn(d, 4 * h) / np.sqrt(d)).astype('f')
        lstm_wh = (rn(h, 4 * h) / np.sqrt(h)).astype('f')
        lstm_b = np.zeros(4 * h).astype('f')
        affine_w = (rn(h, v) / np.sqrt(h)).astype('f')
        affine_b = np.zeros(v).astype('f')
        
        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_w),
            TimeLSTM(lstm_wx, lstm_wh, lstm_b, stateful=True),
            TimeAffine(affine_w, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]
        
        # 모든 가중치와 기울기를 리스트에 모은다
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
            
    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs
    
    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.lstm_layer.reset_state()
        
    def save_params(self, file_name='Rnnlm.pkl'):
        with open(file_name, 'wb') as f:
            pickle.dump(self.params, f)
            
    def load_params(self, file_name='Rnnlm.pkl'):
        with open(file_name, 'rb') as f:
            self.params = pickle.load(f)

# %%
import sys
sys.path.append('..')
import warnings
warnings.filterwarnings('ignore')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm

# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100
time_size = 35
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim=(0,500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티:', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9999.69
# | 에폭 1 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 2965.95
# | 에폭 1 |  반복 41 / 1327 | 시간 12[s] | 퍼플렉서티 1249.24
# | 에폭 1 |  반복 61 / 1327 | 시간 18[s] | 퍼플렉서티 967.95
# | 에폭 1 |  반복 81 / 1327 | 시간 24[s] | 퍼플렉서티 787.41
# | 에폭 1 |  반복 101 / 1327 | 시간 30[s] | 퍼플렉서티 640.80
# | 에폭 1 |  반복 121 / 1327 | 시간 36[s] | 퍼플렉서티 644.64
# | 에폭 1 |  반복 141 / 1327 | 시간 42[s] | 퍼플렉서티 601.95
# | 에폭 1 |  반복 161 / 1327 | 시간 48[s] | 퍼플렉서티 575.05
# | 에폭 1 |  반복 181 / 1327 | 시간 54[s] | 퍼플렉서티 599.45
# | 에폭 1 |  반복 201 / 1327 | 시간 60[s] | 퍼플렉서티 509.93
# | 에폭 1 |  반복 221 / 1327 | 시간 67[s] | 퍼플렉서티 493.49
# | 에폭 1 |  반복 241 / 1327 | 시간 72[s] | 퍼플렉서티 432.88
# | 에폭 1 |  반복 261 / 1327 | 시간 79[s] | 퍼플렉서티 472.65
# | 에폭 1 |  반복 281 / 1327 | 시간 85[s] | 퍼플렉서티 457.88
# | 에폭 1 |  반복 301 / 1327 | 시간 91[s] | 퍼플렉서티 387.75
# | 에폭 1 |  반복 321 / 1327 | 시간 97[s] | 퍼플렉서티 342.87
# | 에폭 1 |  반복 341 / 1327 | 시간 103[s] | 퍼플렉서티 404.17
# | 에폭 1 |  반복 361 / 1327 | 시간 110[s] | 퍼플렉서티 411.53
# | 에폭 1 |  반복 381 / 1327 | 시간 116[s] | 퍼플렉서티 335.32
# | 에폭 1 |  반복 401 / 1327 | 시간 122[s] | 퍼플렉서티 357.42
# | 에폭 1 |  반복 421 / 1327 | 시간 128[s] | 퍼플렉서티 347.09
# | 에폭 1 |  반복 441 / 1327 | 시간 134[s] | 퍼플렉서티 333.34
# | 에폭 1 |  반복 461 / 1327 | 시간 140[s] | 퍼플렉서티 331.47
# | 에폭 1 |  반복 481 / 1327 | 시간 146[s] | 퍼플렉서티 307.97
# | 에폭 1 |  반복 501 / 1327 | 시간 153[s] | 퍼플렉서티 319.39
# | 에폭 1 |  반복 521 / 1327 | 시간 159[s] | 퍼플렉서티 310.14
# | 에폭 1 |  반복 541 / 1327 | 시간 165[s] | 퍼플렉서티 317.80
# | 에폭 1 |  반복 561 / 1327 | 시간 171[s] | 퍼플렉서티 287.98
# | 에폭 1 |  반복 581 / 1327 | 시간 177[s] | 퍼플렉서티 259.75
# | 에폭 1 |  반복 601 / 1327 | 시간 184[s] | 퍼플렉서티 337.95
# | 에폭 1 |  반복 621 / 1327 | 시간 190[s] | 퍼플렉서티 310.96
# | 에폭 1 |  반복 641 / 1327 | 시간 196[s] | 퍼플렉서티 283.42
# | 에폭 1 |  반복 661 / 1327 | 시간 202[s] | 퍼플렉서티 272.38
# | 에폭 1 |  반복 681 / 1327 | 시간 208[s] | 퍼플렉서티 229.36
# | 에폭 1 |  반복 701 / 1327 | 시간 214[s] | 퍼플렉서티 251.91
# | 에폭 1 |  반복 721 / 1327 | 시간 221[s] | 퍼플렉서티 261.17
# | 에폭 1 |  반복 741 / 1327 | 시간 227[s] | 퍼플렉서티 221.27
# | 에폭 1 |  반복 761 / 1327 | 시간 233[s] | 퍼플렉서티 236.54
# | 에폭 1 |  반복 781 / 1327 | 시간 239[s] | 퍼플렉서티 219.50
# | 에폭 1 |  반복 801 / 1327 | 시간 245[s] | 퍼플렉서티 241.52
# | 에폭 1 |  반복 821 / 1327 | 시간 252[s] | 퍼플렉서티 223.92
# | 에폭 1 |  반복 841 / 1327 | 시간 258[s] | 퍼플렉서티 227.67
# | 에폭 1 |  반복 861 / 1327 | 시간 264[s] | 퍼플렉서티 221.79
# | 에폭 1 |  반복 881 / 1327 | 시간 270[s] | 퍼플렉서티 205.83
# | 에폭 1 |  반복 901 / 1327 | 시간 276[s] | 퍼플렉서티 253.20
# | 에폭 1 |  반복 921 / 1327 | 시간 282[s] | 퍼플렉서티 228.40
# | 에폭 1 |  반복 941 / 1327 | 시간 288[s] | 퍼플렉서티 230.61
# | 에폭 1 |  반복 961 / 1327 | 시간 295[s] | 퍼플렉서티 245.79
# | 에폭 1 |  반복 981 / 1327 | 시간 301[s] | 퍼플렉서티 228.83
# | 에폭 1 |  반복 1001 / 1327 | 시간 307[s] | 퍼플렉서티 192.23
# | 에폭 1 |  반복 1021 / 1327 | 시간 313[s] | 퍼플렉서티 226.89
# | 에폭 1 |  반복 1041 / 1327 | 시간 319[s] | 퍼플렉서티 207.37
# | 에폭 1 |  반복 1061 / 1327 | 시간 326[s] | 퍼플렉서티 196.06
# | 에폭 1 |  반복 1081 / 1327 | 시간 331[s] | 퍼플렉서티 167.45
# | 에폭 1 |  반복 1101 / 1327 | 시간 337[s] | 퍼플렉서티 194.29
# | 에폭 1 |  반복 1121 / 1327 | 시간 344[s] | 퍼플렉서티 230.37
# | 에폭 1 |  반복 1141 / 1327 | 시간 350[s] | 퍼플렉서티 206.43
# | 에폭 1 |  반복 1161 / 1327 | 시간 356[s] | 퍼플렉서티 197.86
# | 에폭 1 |  반복 1181 / 1327 | 시간 362[s] | 퍼플렉서티 188.73
# | 에폭 1 |  반복 1201 / 1327 | 시간 369[s] | 퍼플렉서티 161.05
# | 에폭 1 |  반복 1221 / 1327 | 시간 375[s] | 퍼플렉서티 157.60
# | 에폭 1 |  반복 1241 / 1327 | 시간 381[s] | 퍼플렉서티 187.36
# | 에폭 1 |  반복 1261 / 1327 | 시간 387[s] | 퍼플렉서티 171.94
# | 에폭 1 |  반복 1281 / 1327 | 시간 393[s] | 퍼플렉서티 177.11
# | 에폭 1 |  반복 1301 / 1327 | 시간 400[s] | 퍼플렉서티 222.28
# | 에폭 1 |  반복 1321 / 1327 | 시간 406[s] | 퍼플렉서티 210.92
# | 에폭 2 |  반복 1 / 1327 | 시간 408[s] | 퍼플렉서티 226.15
# | 에폭 2 |  반복 21 / 1327 | 시간 414[s] | 퍼플렉서티 202.93
# | 에폭 2 |  반복 41 / 1327 | 시간 421[s] | 퍼플렉서티 190.51
# | 에폭 2 |  반복 61 / 1327 | 시간 427[s] | 퍼플렉서티 174.83
# | 에폭 2 |  반복 81 / 1327 | 시간 433[s] | 퍼플렉서티 159.49
# | 에폭 2 |  반복 101 / 1327 | 시간 439[s] | 퍼플렉서티 153.29
# | 에폭 2 |  반복 121 / 1327 | 시간 445[s] | 퍼플렉서티 159.15
# | 에폭 2 |  반복 141 / 1327 | 시간 452[s] | 퍼플렉서티 177.58
# | 에폭 2 |  반복 161 / 1327 | 시간 458[s] | 퍼플렉서티 192.69
# | 에폭 2 |  반복 181 / 1327 | 시간 464[s] | 퍼플렉서티 201.04
# | 에폭 2 |  반복 201 / 1327 | 시간 470[s] | 퍼플렉서티 184.98
# | 에폭 2 |  반복 221 / 1327 | 시간 477[s] | 퍼플렉서티 183.39
# | 에폭 2 |  반복 241 / 1327 | 시간 483[s] | 퍼플렉서티 176.97
# | 에폭 2 |  반복 261 / 1327 | 시간 489[s] | 퍼플렉서티 185.27
# | 에폭 2 |  반복 281 / 1327 | 시간 495[s] | 퍼플렉서티 185.99
# | 에폭 2 |  반복 301 / 1327 | 시간 502[s] | 퍼플렉서티 166.00
# | 에폭 2 |  반복 321 / 1327 | 시간 508[s] | 퍼플렉서티 137.15
# | 에폭 2 |  반복 341 / 1327 | 시간 514[s] | 퍼플렉서티 173.15
# | 에폭 2 |  반복 361 / 1327 | 시간 520[s] | 퍼플렉서티 197.32
# | 에폭 2 |  반복 381 / 1327 | 시간 527[s] | 퍼플렉서티 153.14
# | 에폭 2 |  반복 401 / 1327 | 시간 533[s] | 퍼플렉서티 166.90
# | 에폭 2 |  반복 421 / 1327 | 시간 539[s] | 퍼플렉서티 154.48
# | 에폭 2 |  반복 441 / 1327 | 시간 545[s] | 퍼플렉서티 161.86
# | 에폭 2 |  반복 461 / 1327 | 시간 552[s] | 퍼플렉서티 157.72
# | 에폭 2 |  반복 481 / 1327 | 시간 558[s] | 퍼플렉서티 156.30
# | 에폭 2 |  반복 501 / 1327 | 시간 564[s] | 퍼플렉서티 169.78
# | 에폭 2 |  반복 521 / 1327 | 시간 570[s] | 퍼플렉서티 173.54
# | 에폭 2 |  반복 541 / 1327 | 시간 576[s] | 퍼플렉서티 174.15
# | 에폭 2 |  반복 561 / 1327 | 시간 582[s] | 퍼플렉서티 154.81
# | 에폭 2 |  반복 581 / 1327 | 시간 589[s] | 퍼플렉서티 137.34
# | 에폭 2 |  반복 601 / 1327 | 시간 595[s] | 퍼플렉서티 188.65
# | 에폭 2 |  반복 621 / 1327 | 시간 601[s] | 퍼플렉서티 179.33
# | 에폭 2 |  반복 641 / 1327 | 시간 607[s] | 퍼플렉서티 164.32
# | 에폭 2 |  반복 661 / 1327 | 시간 613[s] | 퍼플렉서티 155.52
# | 에폭 2 |  반복 681 / 1327 | 시간 619[s] | 퍼플렉서티 129.62
# | 에폭 2 |  반복 701 / 1327 | 시간 625[s] | 퍼플렉서티 149.33
# | 에폭 2 |  반복 721 / 1327 | 시간 632[s] | 퍼플렉서티 159.26
# | 에폭 2 |  반복 741 / 1327 | 시간 638[s] | 퍼플렉서티 132.37
# | 에폭 2 |  반복 761 / 1327 | 시간 644[s] | 퍼플렉서티 130.23
# | 에폭 2 |  반복 781 / 1327 | 시간 650[s] | 퍼플렉서티 135.20
# | 에폭 2 |  반복 801 / 1327 | 시간 657[s] | 퍼플렉서티 147.18
# | 에폭 2 |  반복 821 / 1327 | 시간 663[s] | 퍼플렉서티 143.55
# | 에폭 2 |  반복 841 / 1327 | 시간 669[s] | 퍼플렉서티 144.78
# | 에폭 2 |  반복 861 / 1327 | 시간 675[s] | 퍼플렉서티 144.88
# | 에폭 2 |  반복 881 / 1327 | 시간 682[s] | 퍼플렉서티 129.16
# | 에폭 2 |  반복 901 / 1327 | 시간 688[s] | 퍼플렉서티 167.30
# | 에폭 2 |  반복 921 / 1327 | 시간 694[s] | 퍼플렉서티 147.71
# | 에폭 2 |  반복 941 / 1327 | 시간 700[s] | 퍼플렉서티 153.63
# | 에폭 2 |  반복 961 / 1327 | 시간 706[s] | 퍼플렉서티 163.90
# | 에폭 2 |  반복 981 / 1327 | 시간 713[s] | 퍼플렉서티 154.18
# | 에폭 2 |  반복 1001 / 1327 | 시간 719[s] | 퍼플렉서티 130.24
# | 에폭 2 |  반복 1021 / 1327 | 시간 725[s] | 퍼플렉서티 154.85
# | 에폭 2 |  반복 1041 / 1327 | 시간 731[s] | 퍼플렉서티 143.23
# | 에폭 2 |  반복 1061 / 1327 | 시간 738[s] | 퍼플렉서티 129.26
# | 에폭 2 |  반복 1081 / 1327 | 시간 744[s] | 퍼플렉서티 110.73
# | 에폭 2 |  반복 1101 / 1327 | 시간 750[s] | 퍼플렉서티 121.72
# | 에폭 2 |  반복 1121 / 1327 | 시간 757[s] | 퍼플렉서티 153.93
# | 에폭 2 |  반복 1141 / 1327 | 시간 763[s] | 퍼플렉서티 140.80
# | 에폭 2 |  반복 1161 / 1327 | 시간 769[s] | 퍼플렉서티 131.73
# | 에폭 2 |  반복 1181 / 1327 | 시간 775[s] | 퍼플렉서티 134.47
# | 에폭 2 |  반복 1201 / 1327 | 시간 782[s] | 퍼플렉서티 112.70
# | 에폭 2 |  반복 1221 / 1327 | 시간 788[s] | 퍼플렉서티 109.20
# | 에폭 2 |  반복 1241 / 1327 | 시간 794[s] | 퍼플렉서티 130.14
# | 에폭 2 |  반복 1261 / 1327 | 시간 800[s] | 퍼플렉서티 123.85
# | 에폭 2 |  반복 1281 / 1327 | 시간 807[s] | 퍼플렉서티 122.25
# | 에폭 2 |  반복 1301 / 1327 | 시간 813[s] | 퍼플렉서티 157.54
# | 에폭 2 |  반복 1321 / 1327 | 시간 819[s] | 퍼플렉서티 153.28
# | 에폭 3 |  반복 1 / 1327 | 시간 821[s] | 퍼플렉서티 162.41
# | 에폭 3 |  반복 21 / 1327 | 시간 828[s] | 퍼플렉서티 143.56
# | 에폭 3 |  반복 41 / 1327 | 시간 834[s] | 퍼플렉서티 136.80
# | 에폭 3 |  반복 61 / 1327 | 시간 840[s] | 퍼플렉서티 127.44
# | 에폭 3 |  반복 81 / 1327 | 시간 847[s] | 퍼플렉서티 117.34
# | 에폭 3 |  반복 101 / 1327 | 시간 853[s] | 퍼플렉서티 105.23
# | 에폭 3 |  반복 121 / 1327 | 시간 859[s] | 퍼플렉서티 116.54
# | 에폭 3 |  반복 141 / 1327 | 시간 865[s] | 퍼플렉서티 126.53
# | 에폭 3 |  반복 161 / 1327 | 시간 871[s] | 퍼플렉서티 141.50
# | 에폭 3 |  반복 181 / 1327 | 시간 878[s] | 퍼플렉서티 150.89
# | 에폭 3 |  반복 201 / 1327 | 시간 884[s] | 퍼플렉서티 139.46
# | 에폭 3 |  반복 221 / 1327 | 시간 890[s] | 퍼플렉서티 141.42
# | 에폭 3 |  반복 241 / 1327 | 시간 896[s] | 퍼플렉서티 134.90
# | 에폭 3 |  반복 261 / 1327 | 시간 903[s] | 퍼플렉서티 139.09
# | 에폭 3 |  반복 281 / 1327 | 시간 909[s] | 퍼플렉서티 141.87
# | 에폭 3 |  반복 301 / 1327 | 시간 915[s] | 퍼플렉서티 123.16
# | 에폭 3 |  반복 321 / 1327 | 시간 921[s] | 퍼플렉서티 101.98
# | 에폭 3 |  반복 341 / 1327 | 시간 928[s] | 퍼플렉서티 124.52
# | 에폭 3 |  반복 361 / 1327 | 시간 934[s] | 퍼플렉서티 152.31
# | 에폭 3 |  반복 381 / 1327 | 시간 940[s] | 퍼플렉서티 115.15
# | 에폭 3 |  반복 401 / 1327 | 시간 947[s] | 퍼플렉서티 129.34
# | 에폭 3 |  반복 421 / 1327 | 시간 953[s] | 퍼플렉서티 114.98
# | 에폭 3 |  반복 441 / 1327 | 시간 959[s] | 퍼플렉서티 123.55
# | 에폭 3 |  반복 461 / 1327 | 시간 965[s] | 퍼플렉서티 117.84
# | 에폭 3 |  반복 481 / 1327 | 시간 972[s] | 퍼플렉서티 119.92
# | 에폭 3 |  반복 501 / 1327 | 시간 978[s] | 퍼플렉서티 129.87
# | 에폭 3 |  반복 521 / 1327 | 시간 984[s] | 퍼플렉서티 138.35
# | 에폭 3 |  반복 541 / 1327 | 시간 990[s] | 퍼플렉서티 136.70
# | 에폭 3 |  반복 561 / 1327 | 시간 997[s] | 퍼플렉서티 118.55
# | 에폭 3 |  반복 581 / 1327 | 시간 1003[s] | 퍼플렉서티 105.74
# | 에폭 3 |  반복 601 / 1327 | 시간 1009[s] | 퍼플렉서티 148.99
# | 에폭 3 |  반복 621 / 1327 | 시간 1015[s] | 퍼플렉서티 142.76
# | 에폭 3 |  반복 641 / 1327 | 시간 1022[s] | 퍼플렉서티 130.54
# | 에폭 3 |  반복 661 / 1327 | 시간 1028[s] | 퍼플렉서티 121.14
# | 에폭 3 |  반복 681 / 1327 | 시간 1034[s] | 퍼플렉서티 100.90
# | 에폭 3 |  반복 701 / 1327 | 시간 1040[s] | 퍼플렉서티 118.81
# | 에폭 3 |  반복 721 / 1327 | 시간 1046[s] | 퍼플렉서티 126.50
# | 에폭 3 |  반복 741 / 1327 | 시간 1053[s] | 퍼플렉서티 107.83
# | 에폭 3 |  반복 761 / 1327 | 시간 1059[s] | 퍼플렉서티 102.10
# | 에폭 3 |  반복 781 / 1327 | 시간 1065[s] | 퍼플렉서티 105.66
# | 에폭 3 |  반복 801 / 1327 | 시간 1071[s] | 퍼플렉서티 117.63
# | 에폭 3 |  반복 821 / 1327 | 시간 1077[s] | 퍼플렉서티 116.98
# | 에폭 3 |  반복 841 / 1327 | 시간 1083[s] | 퍼플렉서티 115.40
# | 에폭 3 |  반복 861 / 1327 | 시간 1090[s] | 퍼플렉서티 119.13
# | 에폭 3 |  반복 881 / 1327 | 시간 1096[s] | 퍼플렉서티 105.16
# | 에폭 3 |  반복 901 / 1327 | 시간 1102[s] | 퍼플렉서티 132.34
# | 에폭 3 |  반복 921 / 1327 | 시간 1108[s] | 퍼플렉서티 118.51
# | 에폭 3 |  반복 941 / 1327 | 시간 1114[s] | 퍼플렉서티 127.24
# | 에폭 3 |  반복 961 / 1327 | 시간 1119[s] | 퍼플렉서티 131.42
# | 에폭 3 |  반복 981 / 1327 | 시간 1125[s] | 퍼플렉서티 124.34
# | 에폭 3 |  반복 1001 / 1327 | 시간 1131[s] | 퍼플렉서티 107.57
# | 에폭 3 |  반복 1021 / 1327 | 시간 1138[s] | 퍼플렉서티 127.65
# | 에폭 3 |  반복 1041 / 1327 | 시간 1144[s] | 퍼플렉서티 119.48
# | 에폭 3 |  반복 1061 / 1327 | 시간 1150[s] | 퍼플렉서티 103.90
# | 에폭 3 |  반복 1081 / 1327 | 시간 1156[s] | 퍼플렉서티 88.36
# | 에폭 3 |  반복 1101 / 1327 | 시간 1162[s] | 퍼플렉서티 96.48
# | 에폭 3 |  반복 1121 / 1327 | 시간 1169[s] | 퍼플렉서티 121.97
# | 에폭 3 |  반복 1141 / 1327 | 시간 1175[s] | 퍼플렉서티 115.40
# | 에폭 3 |  반복 1161 / 1327 | 시간 1181[s] | 퍼플렉서티 106.03
# | 에폭 3 |  반복 1181 / 1327 | 시간 1187[s] | 퍼플렉서티 111.45
# | 에폭 3 |  반복 1201 / 1327 | 시간 1194[s] | 퍼플렉서티 94.75
# | 에폭 3 |  반복 1221 / 1327 | 시간 1200[s] | 퍼플렉서티 88.56
# | 에폭 3 |  반복 1241 / 1327 | 시간 1206[s] | 퍼플렉서티 105.91
# | 에폭 3 |  반복 1261 / 1327 | 시간 1212[s] | 퍼플렉서티 106.18
# | 에폭 3 |  반복 1281 / 1327 | 시간 1218[s] | 퍼플렉서티 101.05
# | 에폭 3 |  반복 1301 / 1327 | 시간 1224[s] | 퍼플렉서티 129.55
# | 에폭 3 |  반복 1321 / 1327 | 시간 1231[s] | 퍼플렉서티 127.39
# | 에폭 4 |  반복 1 / 1327 | 시간 1233[s] | 퍼플렉서티 136.58
# | 에폭 4 |  반복 21 / 1327 | 시간 1239[s] | 퍼플렉서티 121.44
# | 에폭 4 |  반복 41 / 1327 | 시간 1245[s] | 퍼플렉서티 107.91
# | 에폭 4 |  반복 61 / 1327 | 시간 1251[s] | 퍼플렉서티 108.56
# | 에폭 4 |  반복 81 / 1327 | 시간 1257[s] | 퍼플렉서티 97.12
# | 에폭 4 |  반복 101 / 1327 | 시간 1264[s] | 퍼플렉서티 86.84
# | 에폭 4 |  반복 121 / 1327 | 시간 1270[s] | 퍼플렉서티 96.37
# | 에폭 4 |  반복 141 / 1327 | 시간 1276[s] | 퍼플렉서티 103.55
# | 에폭 4 |  반복 161 / 1327 | 시간 1282[s] | 퍼플렉서티 117.32
# | 에폭 4 |  반복 181 / 1327 | 시간 1288[s] | 퍼플렉서티 129.21
# | 에폭 4 |  반복 201 / 1327 | 시간 1294[s] | 퍼플렉서티 118.36
# | 에폭 4 |  반복 221 / 1327 | 시간 1300[s] | 퍼플렉서티 122.98
# | 에폭 4 |  반복 241 / 1327 | 시간 1307[s] | 퍼플렉서티 114.51
# | 에폭 4 |  반복 261 / 1327 | 시간 1313[s] | 퍼플렉서티 114.19
# | 에폭 4 |  반복 281 / 1327 | 시간 1319[s] | 퍼플렉서티 121.86
# | 에폭 4 |  반복 301 / 1327 | 시간 1325[s] | 퍼플렉서티 104.25
# | 에폭 4 |  반복 321 / 1327 | 시간 1331[s] | 퍼플렉서티 84.61
# | 에폭 4 |  반복 341 / 1327 | 시간 1338[s] | 퍼플렉서티 102.01
# | 에폭 4 |  반복 361 / 1327 | 시간 1344[s] | 퍼플렉서티 128.78
# | 에폭 4 |  반복 381 / 1327 | 시간 1350[s] | 퍼플렉서티 98.06
# | 에폭 4 |  반복 401 / 1327 | 시간 1356[s] | 퍼플렉서티 110.63
# | 에폭 4 |  반복 421 / 1327 | 시간 1363[s] | 퍼플렉서티 94.98
# | 에폭 4 |  반복 441 / 1327 | 시간 1369[s] | 퍼플렉서티 103.55
# | 에폭 4 |  반복 461 / 1327 | 시간 1375[s] | 퍼플렉서티 99.99
# | 에폭 4 |  반복 481 / 1327 | 시간 1381[s] | 퍼플렉서티 102.75
# | 에폭 4 |  반복 501 / 1327 | 시간 1387[s] | 퍼플렉서티 109.32
# | 에폭 4 |  반복 521 / 1327 | 시간 1394[s] | 퍼플렉서티 116.54
# | 에폭 4 |  반복 541 / 1327 | 시간 1400[s] | 퍼플렉서티 114.03
# | 에폭 4 |  반복 561 / 1327 | 시간 1406[s] | 퍼플렉서티 102.75
# | 에폭 4 |  반복 581 / 1327 | 시간 1412[s] | 퍼플렉서티 89.49
# | 에폭 4 |  반복 601 / 1327 | 시간 1418[s] | 퍼플렉서티 127.06
# | 에폭 4 |  반복 621 / 1327 | 시간 1425[s] | 퍼플렉서티 121.47
# | 에폭 4 |  반복 641 / 1327 | 시간 1431[s] | 퍼플렉서티 110.22
# | 에폭 4 |  반복 661 / 1327 | 시간 1437[s] | 퍼플렉서티 103.56
# | 에폭 4 |  반복 681 / 1327 | 시간 1443[s] | 퍼플렉서티 85.27
# | 에폭 4 |  반복 701 / 1327 | 시간 1449[s] | 퍼플렉서티 102.71
# | 에폭 4 |  반복 721 / 1327 | 시간 1456[s] | 퍼플렉서티 107.74
# | 에폭 4 |  반복 741 / 1327 | 시간 1462[s] | 퍼플렉서티 95.30
# | 에폭 4 |  반복 761 / 1327 | 시간 1468[s] | 퍼플렉서티 88.22
# | 에폭 4 |  반복 781 / 1327 | 시간 1474[s] | 퍼플렉서티 89.53
# | 에폭 4 |  반복 801 / 1327 | 시간 1480[s] | 퍼플렉서티 99.44
# | 에폭 4 |  반복 821 / 1327 | 시간 1486[s] | 퍼플렉서티 103.19
# | 에폭 4 |  반복 841 / 1327 | 시간 1493[s] | 퍼플렉서티 99.17
# | 에폭 4 |  반복 861 / 1327 | 시간 1499[s] | 퍼플렉서티 103.86
# | 에폭 4 |  반복 881 / 1327 | 시간 1505[s] | 퍼플렉서티 91.21
# | 에폭 4 |  반복 901 / 1327 | 시간 1511[s] | 퍼플렉서티 114.20
# | 에폭 4 |  반복 921 / 1327 | 시간 1518[s] | 퍼플렉서티 102.35
# | 에폭 4 |  반복 941 / 1327 | 시간 1524[s] | 퍼플렉서티 111.80
# | 에폭 4 |  반복 961 / 1327 | 시간 1530[s] | 퍼플렉서티 111.93
# | 에폭 4 |  반복 981 / 1327 | 시간 1536[s] | 퍼플렉서티 108.02
# | 에폭 4 |  반복 1001 / 1327 | 시간 1542[s] | 퍼플렉서티 96.25
# | 에폭 4 |  반복 1021 / 1327 | 시간 1549[s] | 퍼플렉서티 112.60
# | 에폭 4 |  반복 1041 / 1327 | 시간 1555[s] | 퍼플렉서티 103.86
# | 에폭 4 |  반복 1061 / 1327 | 시간 1561[s] | 퍼플렉서티 89.11
# | 에폭 4 |  반복 1081 / 1327 | 시간 1567[s] | 퍼플렉서티 78.03
# | 에폭 4 |  반복 1101 / 1327 | 시간 1573[s] | 퍼플렉서티 81.81
# | 에폭 4 |  반복 1121 / 1327 | 시간 1580[s] | 퍼플렉서티 103.82
# | 에폭 4 |  반복 1141 / 1327 | 시간 1586[s] | 퍼플렉서티 100.19
# | 에폭 4 |  반복 1161 / 1327 | 시간 1592[s] | 퍼플렉서티 91.10
# | 에폭 4 |  반복 1181 / 1327 | 시간 1598[s] | 퍼플렉서티 96.12
# | 에폭 4 |  반복 1201 / 1327 | 시간 1605[s] | 퍼플렉서티 84.31
# | 에폭 4 |  반복 1221 / 1327 | 시간 1611[s] | 퍼플렉서티 76.01
# | 에폭 4 |  반복 1241 / 1327 | 시간 1617[s] | 퍼플렉서티 91.37
# | 에폭 4 |  반복 1261 / 1327 | 시간 1623[s] | 퍼플렉서티 93.85
# | 에폭 4 |  반복 1281 / 1327 | 시간 1629[s] | 퍼플렉서티 89.33
# | 에폭 4 |  반복 1301 / 1327 | 시간 1636[s] | 퍼플렉서티 110.94
# | 에폭 4 |  반복 1321 / 1327 | 시간 1642[s] | 퍼플렉서티 110.62
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티: 137.2640377557064

# %%
import sys
sys.path.append('..')
from common import config
config.GPU = True
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from better_rnnlm import BetterRnnlm

# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 5
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

vocab_size = len(word_to_id)
xs = corpus[:-1]
tx = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size, time_size=time_size, max_grad=max_grad)
    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티:', ppl)
    
    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr
    
    model.reset_state()
    print('-'*50)
# Out:
# Downloading ptb.valid.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 2[s] | 퍼플렉서티 10000.54
# | 에폭 1 |  반복 21 / 1327 | 시간 43[s] | 퍼플렉서티 3975.32
# | 에폭 1 |  반복 41 / 1327 | 시간 72[s] | 퍼플렉서티 1867.96
# | 에폭 1 |  반복 61 / 1327 | 시간 102[s] | 퍼플렉서티 1317.30
# | 에폭 1 |  반복 81 / 1327 | 시간 133[s] | 퍼플렉서티 1054.15
# | 에폭 1 |  반복 101 / 1327 | 시간 164[s] | 퍼플렉서티 828.45
# | 에폭 1 |  반복 121 / 1327 | 시간 195[s] | 퍼플렉서티 788.93
# | 에폭 1 |  반복 141 / 1327 | 시간 226[s] | 퍼플렉서티 722.85
# | 에폭 1 |  반복 161 / 1327 | 시간 257[s] | 퍼플렉서티 671.91
# | 에폭 1 |  반복 181 / 1327 | 시간 288[s] | 퍼플렉서티 682.67
# | 에폭 1 |  반복 201 / 1327 | 시간 319[s] | 퍼플렉서티 581.88
# | 에폭 1 |  반복 221 / 1327 | 시간 349[s] | 퍼플렉서티 565.79
# | 에폭 1 |  반복 241 / 1327 | 시간 380[s] | 퍼플렉서티 518.84
# | 에폭 1 |  반복 261 / 1327 | 시간 411[s] | 퍼플렉서티 526.93
# | 에폭 1 |  반복 281 / 1327 | 시간 442[s] | 퍼플렉서티 516.16
# | 에폭 1 |  반복 301 / 1327 | 시간 473[s] | 퍼플렉서티 443.10
# | 에폭 1 |  반복 321 / 1327 | 시간 503[s] | 퍼플렉서티 394.02
# | 에폭 1 |  반복 341 / 1327 | 시간 534[s] | 퍼플렉서티 457.22
# | 에폭 1 |  반복 361 / 1327 | 시간 564[s] | 퍼플렉서티 457.86
# | 에폭 1 |  반복 381 / 1327 | 시간 595[s] | 퍼플렉서티 382.75
# | 에폭 1 |  반복 401 / 1327 | 시간 625[s] | 퍼플렉서티 400.32
# | 에폭 1 |  반복 421 / 1327 | 시간 656[s] | 퍼플렉서티 394.08
# | 에폭 1 |  반복 441 / 1327 | 시간 686[s] | 퍼플렉서티 378.09
# | 에폭 1 |  반복 461 / 1327 | 시간 716[s] | 퍼플렉서티 372.69
# | 에폭 1 |  반복 481 / 1327 | 시간 746[s] | 퍼플렉서티 344.07
# | 에폭 1 |  반복 501 / 1327 | 시간 775[s] | 퍼플렉서티 359.24
# | 에폭 1 |  반복 521 / 1327 | 시간 805[s] | 퍼플렉서티 339.64
# | 에폭 1 |  반복 541 / 1327 | 시간 835[s] | 퍼플렉서티 362.38
# | 에폭 1 |  반복 561 / 1327 | 시간 864[s] | 퍼플렉서티 319.21
# | 에폭 1 |  반복 581 / 1327 | 시간 894[s] | 퍼플렉서티 291.45
# | 에폭 1 |  반복 601 / 1327 | 시간 924[s] | 퍼플렉서티 376.58
# | 에폭 1 |  반복 621 / 1327 | 시간 954[s] | 퍼플렉서티 349.34
# | 에폭 1 |  반복 641 / 1327 | 시간 984[s] | 퍼플렉서티 311.74
# | 에폭 1 |  반복 661 / 1327 | 시간 1013[s] | 퍼플렉서티 303.48
# | 에폭 1 |  반복 681 / 1327 | 시간 1043[s] | 퍼플렉서티 256.59
# | 에폭 1 |  반복 701 / 1327 | 시간 1073[s] | 퍼플렉서티 277.90
# | 에폭 1 |  반복 721 / 1327 | 시간 1104[s] | 퍼플렉서티 288.41
# | 에폭 1 |  반복 741 / 1327 | 시간 1133[s] | 퍼플렉서티 246.29
# | 에폭 1 |  반복 761 / 1327 | 시간 1163[s] | 퍼플렉서티 260.89
# | 에폭 1 |  반복 781 / 1327 | 시간 1193[s] | 퍼플렉서티 240.64
# | 에폭 1 |  반복 801 / 1327 | 시간 1223[s] | 퍼플렉서티 268.41
# | 에폭 1 |  반복 821 / 1327 | 시간 1253[s] | 퍼플렉서티 249.77
# | 에폭 1 |  반복 841 / 1327 | 시간 1283[s] | 퍼플렉서티 255.16
# | 에폭 1 |  반복 861 / 1327 | 시간 1313[s] | 퍼플렉서티 247.21
# | 에폭 1 |  반복 881 / 1327 | 시간 1343[s] | 퍼플렉서티 231.46
# | 에폭 1 |  반복 901 / 1327 | 시간 1373[s] | 퍼플렉서티 281.36
# | 에폭 1 |  반복 921 / 1327 | 시간 1403[s] | 퍼플렉서티 253.46
# | 에폭 1 |  반복 941 / 1327 | 시간 1433[s] | 퍼플렉서티 256.50
# | 에폭 1 |  반복 961 / 1327 | 시간 1463[s] | 퍼플렉서티 271.20
# | 에폭 1 |  반복 981 / 1327 | 시간 1493[s] | 퍼플렉서티 254.38
# | 에폭 1 |  반복 1001 / 1327 | 시간 1523[s] | 퍼플렉서티 212.42
# | 에폭 1 |  반복 1021 / 1327 | 시간 1553[s] | 퍼플렉서티 252.22
# | 에폭 1 |  반복 1041 / 1327 | 시간 1583[s] | 퍼플렉서티 231.68
# | 에폭 1 |  반복 1061 / 1327 | 시간 1613[s] | 퍼플렉서티 216.84
# | 에폭 1 |  반복 1081 / 1327 | 시간 1642[s] | 퍼플렉서티 188.68
# | 에폭 1 |  반복 1101 / 1327 | 시간 1672[s] | 퍼플렉서티 215.53
# | 에폭 1 |  반복 1121 / 1327 | 시간 1702[s] | 퍼플렉서티 255.14
# | 에폭 1 |  반복 1141 / 1327 | 시간 1732[s] | 퍼플렉서티 231.93
# | 에폭 1 |  반복 1161 / 1327 | 시간 1761[s] | 퍼플렉서티 217.89
# | 에폭 1 |  반복 1181 / 1327 | 시간 1791[s] | 퍼플렉서티 206.90
# | 에폭 1 |  반복 1201 / 1327 | 시간 1821[s] | 퍼플렉서티 181.04
# | 에폭 1 |  반복 1221 / 1327 | 시간 1851[s] | 퍼플렉서티 178.66
# | 에폭 1 |  반복 1241 / 1327 | 시간 1881[s] | 퍼플렉서티 208.68
# | 에폭 1 |  반복 1261 / 1327 | 시간 1910[s] | 퍼플렉서티 189.78
# | 에폭 1 |  반복 1281 / 1327 | 시간 1940[s] | 퍼플렉서티 196.84
# | 에폭 1 |  반복 1301 / 1327 | 시간 1970[s] | 퍼플렉서티 244.43
# | 에폭 1 |  반복 1321 / 1327 | 시간 2000[s] | 퍼플렉서티 230.24
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티: 199.7977137074875
# --------------------------------------------------
# | 에폭 2 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 292.25
# | 에폭 2 |  반복 21 / 1327 | 시간 31[s] | 퍼플렉서티 229.01
# | 에폭 2 |  반복 41 / 1327 | 시간 60[s] | 퍼플렉서티 212.65
# | 에폭 2 |  반복 61 / 1327 | 시간 90[s] | 퍼플렉서티 193.82
# | 에폭 2 |  반복 81 / 1327 | 시간 121[s] | 퍼플렉서티 180.44
# | 에폭 2 |  반복 101 / 1327 | 시간 151[s] | 퍼플렉서티 168.17
# | 에폭 2 |  반복 121 / 1327 | 시간 181[s] | 퍼플렉서티 181.76
# | 에폭 2 |  반복 141 / 1327 | 시간 210[s] | 퍼플렉서티 201.86
# | 에폭 2 |  반복 161 / 1327 | 시간 240[s] | 퍼플렉서티 213.80
# | 에폭 2 |  반복 181 / 1327 | 시간 270[s] | 퍼플렉서티 220.66
# | 에폭 2 |  반복 201 / 1327 | 시간 300[s] | 퍼플렉서티 204.55
# | 에폭 2 |  반복 221 / 1327 | 시간 330[s] | 퍼플렉서티 202.84
# | 에폭 2 |  반복 241 / 1327 | 시간 360[s] | 퍼플렉서티 195.05
# | 에폭 2 |  반복 261 / 1327 | 시간 390[s] | 퍼플렉서티 213.43
# | 에폭 2 |  반복 281 / 1327 | 시간 420[s] | 퍼플렉서티 203.27
# | 에폭 2 |  반복 301 / 1327 | 시간 449[s] | 퍼플렉서티 185.88
# | 에폭 2 |  반복 321 / 1327 | 시간 479[s] | 퍼플렉서티 154.42
# | 에폭 2 |  반복 341 / 1327 | 시간 509[s] | 퍼플렉서티 199.51
# | 에폭 2 |  반복 361 / 1327 | 시간 539[s] | 퍼플렉서티 214.49
# | 에폭 2 |  반복 381 / 1327 | 시간 569[s] | 퍼플렉서티 171.85
# | 에폭 2 |  반복 401 / 1327 | 시간 599[s] | 퍼플렉서티 192.55
# | 에폭 2 |  반복 421 / 1327 | 시간 629[s] | 퍼플렉서티 177.39
# | 에폭 2 |  반복 441 / 1327 | 시간 659[s] | 퍼플렉서티 178.80
# | 에폭 2 |  반복 461 / 1327 | 시간 688[s] | 퍼플렉서티 182.50
# | 에폭 2 |  반복 481 / 1327 | 시간 718[s] | 퍼플렉서티 174.09
# | 에폭 2 |  반복 501 / 1327 | 시간 748[s] | 퍼플렉서티 190.09
# | 에폭 2 |  반복 521 / 1327 | 시간 779[s] | 퍼플렉서티 190.81
# | 에폭 2 |  반복 541 / 1327 | 시간 809[s] | 퍼플렉서티 200.30
# | 에폭 2 |  반복 561 / 1327 | 시간 839[s] | 퍼플렉서티 172.46
# | 에폭 2 |  반복 581 / 1327 | 시간 869[s] | 퍼플렉서티 155.65
# | 에폭 2 |  반복 601 / 1327 | 시간 899[s] | 퍼플렉서티 213.73
# | 에폭 2 |  반복 621 / 1327 | 시간 929[s] | 퍼플렉서티 201.30
# | 에폭 2 |  반복 641 / 1327 | 시간 959[s] | 퍼플렉서티 182.10
# | 에폭 2 |  반복 661 / 1327 | 시간 989[s] | 퍼플렉서티 174.11
# | 에폭 2 |  반복 681 / 1327 | 시간 1019[s] | 퍼플렉서티 147.14
# | 에폭 2 |  반복 701 / 1327 | 시간 1049[s] | 퍼플렉서티 169.71
# | 에폭 2 |  반복 721 / 1327 | 시간 1079[s] | 퍼플렉서티 175.93
# | 에폭 2 |  반복 741 / 1327 | 시간 1109[s] | 퍼플렉서티 150.89
# | 에폭 2 |  반복 761 / 1327 | 시간 1142[s] | 퍼플렉서티 149.55
# | 에폭 2 |  반복 781 / 1327 | 시간 1172[s] | 퍼플렉서티 149.49
# | 에폭 2 |  반복 801 / 1327 | 시간 1202[s] | 퍼플렉서티 171.74
# | 에폭 2 |  반복 821 / 1327 | 시간 1232[s] | 퍼플렉서티 163.33
# | 에폭 2 |  반복 841 / 1327 | 시간 1261[s] | 퍼플렉서티 163.75
# | 에폭 2 |  반복 861 / 1327 | 시간 1291[s] | 퍼플렉서티 161.60
# | 에폭 2 |  반복 881 / 1327 | 시간 1321[s] | 퍼플렉서티 147.72
# | 에폭 2 |  반복 901 / 1327 | 시간 1351[s] | 퍼플렉서티 189.70
# | 에폭 2 |  반복 921 / 1327 | 시간 1381[s] | 퍼플렉서티 165.22
# | 에폭 2 |  반복 941 / 1327 | 시간 1410[s] | 퍼플렉서티 169.11
# | 에폭 2 |  반복 961 / 1327 | 시간 1440[s] | 퍼플렉서티 185.40
# | 에폭 2 |  반복 981 / 1327 | 시간 1470[s] | 퍼플렉서티 172.93
# | 에폭 2 |  반복 1001 / 1327 | 시간 1500[s] | 퍼플렉서티 147.79
# | 에폭 2 |  반복 1021 / 1327 | 시간 1532[s] | 퍼플렉서티 175.05
# | 에폭 2 |  반복 1041 / 1327 | 시간 1563[s] | 퍼플렉서티 158.55
# | 에폭 2 |  반복 1061 / 1327 | 시간 1595[s] | 퍼플렉서티 147.13
# | 에폭 2 |  반복 1081 / 1327 | 시간 1627[s] | 퍼플렉서티 123.07
# | 에폭 2 |  반복 1101 / 1327 | 시간 1659[s] | 퍼플렉서티 138.01
# | 에폭 2 |  반복 1121 / 1327 | 시간 1692[s] | 퍼플렉서티 172.35
# | 에폭 2 |  반복 1141 / 1327 | 시간 1724[s] | 퍼플렉서티 161.32
# | 에폭 2 |  반복 1161 / 1327 | 시간 1756[s] | 퍼플렉서티 146.58
# | 에폭 2 |  반복 1181 / 1327 | 시간 1788[s] | 퍼플렉서티 148.15
# | 에폭 2 |  반복 1201 / 1327 | 시간 1819[s] | 퍼플렉서티 126.00
# | 에폭 2 |  반복 1221 / 1327 | 시간 1851[s] | 퍼플렉서티 125.23
# | 에폭 2 |  반복 1241 / 1327 | 시간 1882[s] | 퍼플렉서티 147.53
# | 에폭 2 |  반복 1261 / 1327 | 시간 1914[s] | 퍼플렉서티 137.67
# | 에폭 2 |  반복 1281 / 1327 | 시간 1945[s] | 퍼플렉서티 141.14
# | 에폭 2 |  반복 1301 / 1327 | 시간 1975[s] | 퍼플렉서티 176.96
# | 에폭 2 |  반복 1321 / 1327 | 시간 2006[s] | 퍼플렉서티 168.53
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티: 144.84138443076506
# --------------------------------------------------
# | 에폭 3 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 217.05
# | 에폭 3 |  반복 21 / 1327 | 시간 31[s] | 퍼플렉서티 160.43
# | 에폭 3 |  반복 41 / 1327 | 시간 62[s] | 퍼플렉서티 152.48
# | 에폭 3 |  반복 61 / 1327 | 시간 94[s] | 퍼플렉서티 143.32
# | 에폭 3 |  반복 81 / 1327 | 시간 125[s] | 퍼플렉서티 126.46
# | 에폭 3 |  반복 101 / 1327 | 시간 156[s] | 퍼플렉서티 120.29
# | 에폭 3 |  반복 121 / 1327 | 시간 187[s] | 퍼플렉서티 133.22
# | 에폭 3 |  반복 141 / 1327 | 시간 218[s] | 퍼플렉서티 146.83
# | 에폭 3 |  반복 161 / 1327 | 시간 249[s] | 퍼플렉서티 160.80
# | 에폭 3 |  반복 181 / 1327 | 시간 280[s] | 퍼플렉서티 169.33
# | 에폭 3 |  반복 201 / 1327 | 시간 311[s] | 퍼플렉서티 158.74
# | 에폭 3 |  반복 221 / 1327 | 시간 342[s] | 퍼플렉서티 156.28
# | 에폭 3 |  반복 241 / 1327 | 시간 373[s] | 퍼플렉서티 149.03
# | 에폭 3 |  반복 261 / 1327 | 시간 404[s] | 퍼플렉서티 163.57
# | 에폭 3 |  반복 281 / 1327 | 시간 435[s] | 퍼플렉서티 158.85
# | 에폭 3 |  반복 301 / 1327 | 시간 467[s] | 퍼플렉서티 140.73
# | 에폭 3 |  반복 321 / 1327 | 시간 499[s] | 퍼플렉서티 110.19
# | 에폭 3 |  반복 341 / 1327 | 시간 530[s] | 퍼플렉서티 152.27
# | 에폭 3 |  반복 361 / 1327 | 시간 561[s] | 퍼플렉서티 164.98
# | 에폭 3 |  반복 381 / 1327 | 시간 592[s] | 퍼플렉서티 131.62
# | 에폭 3 |  반복 401 / 1327 | 시간 624[s] | 퍼플렉서티 150.75
# | 에폭 3 |  반복 421 / 1327 | 시간 656[s] | 퍼플렉서티 130.18
# | 에폭 3 |  반복 441 / 1327 | 시간 687[s] | 퍼플렉서티 139.64
# | 에폭 3 |  반복 461 / 1327 | 시간 719[s] | 퍼플렉서티 138.36
# | 에폭 3 |  반복 481 / 1327 | 시간 750[s] | 퍼플렉서티 133.80
# | 에폭 3 |  반복 501 / 1327 | 시간 781[s] | 퍼플렉서티 150.05
# | 에폭 3 |  반복 521 / 1327 | 시간 812[s] | 퍼플렉서티 152.76
# | 에폭 3 |  반복 541 / 1327 | 시간 844[s] | 퍼플렉서티 156.53
# | 에폭 3 |  반복 561 / 1327 | 시간 878[s] | 퍼플렉서티 131.29
# | 에폭 3 |  반복 581 / 1327 | 시간 909[s] | 퍼플렉서티 122.46
# | 에폭 3 |  반복 601 / 1327 | 시간 940[s] | 퍼플렉서티 169.17
# | 에폭 3 |  반복 621 / 1327 | 시간 972[s] | 퍼플렉서티 159.17
# | 에폭 3 |  반복 641 / 1327 | 시간 1003[s] | 퍼플렉서티 146.34
# | 에폭 3 |  반복 661 / 1327 | 시간 1034[s] | 퍼플렉서티 136.19
# | 에폭 3 |  반복 681 / 1327 | 시간 1065[s] | 퍼플렉서티 116.50
# | 에폭 3 |  반복 701 / 1327 | 시간 1096[s] | 퍼플렉서티 137.02
# | 에폭 3 |  반복 721 / 1327 | 시간 1127[s] | 퍼플렉서티 139.56
# | 에폭 3 |  반복 741 / 1327 | 시간 1159[s] | 퍼플렉서티 119.89
# | 에폭 3 |  반복 761 / 1327 | 시간 1191[s] | 퍼플렉서티 113.81
# | 에폭 3 |  반복 781 / 1327 | 시간 1224[s] | 퍼플렉서티 119.29
# | 에폭 3 |  반복 801 / 1327 | 시간 1255[s] | 퍼플렉서티 137.65
# | 에폭 3 |  반복 821 / 1327 | 시간 1286[s] | 퍼플렉서티 132.00
# | 에폭 3 |  반복 841 / 1327 | 시간 1317[s] | 퍼플렉서티 132.76
# | 에폭 3 |  반복 861 / 1327 | 시간 1348[s] | 퍼플렉서티 130.25
# | 에폭 3 |  반복 881 / 1327 | 시간 1379[s] | 퍼플렉서티 120.40
# | 에폭 3 |  반복 901 / 1327 | 시간 1410[s] | 퍼플렉서티 152.65
# | 에폭 3 |  반복 921 / 1327 | 시간 1441[s] | 퍼플렉서티 133.92
# | 에폭 3 |  반복 941 / 1327 | 시간 1472[s] | 퍼플렉서티 139.35
# | 에폭 3 |  반복 961 / 1327 | 시간 1503[s] | 퍼플렉서티 150.56
# | 에폭 3 |  반복 981 / 1327 | 시간 1534[s] | 퍼플렉서티 142.26
# | 에폭 3 |  반복 1001 / 1327 | 시간 1566[s] | 퍼플렉서티 122.13
# | 에폭 3 |  반복 1021 / 1327 | 시간 1596[s] | 퍼플렉서티 145.55
# | 에폭 3 |  반복 1041 / 1327 | 시간 1628[s] | 퍼플렉서티 129.04
# | 에폭 3 |  반복 1061 / 1327 | 시간 1659[s] | 퍼플렉서티 120.75
# | 에폭 3 |  반복 1081 / 1327 | 시간 1690[s] | 퍼플렉서티 99.78
# | 에폭 3 |  반복 1101 / 1327 | 시간 1723[s] | 퍼플렉서티 106.27
# | 에폭 3 |  반복 1121 / 1327 | 시간 1757[s] | 퍼플렉서티 140.59
# | 에폭 3 |  반복 1141 / 1327 | 시간 1790[s] | 퍼플렉서티 134.42
# | 에폭 3 |  반복 1161 / 1327 | 시간 1823[s] | 퍼플렉서티 116.44
# | 에폭 3 |  반복 1181 / 1327 | 시간 1856[s] | 퍼플렉서티 123.97
# | 에폭 3 |  반복 1201 / 1327 | 시간 1888[s] | 퍼플렉서티 103.71
# | 에폭 3 |  반복 1221 / 1327 | 시간 1921[s] | 퍼플렉서티 102.69
# | 에폭 3 |  반복 1241 / 1327 | 시간 1954[s] | 퍼플렉서티 122.07
# | 에폭 3 |  반복 1261 / 1327 | 시간 1987[s] | 퍼플렉서티 115.57
# | 에폭 3 |  반복 1281 / 1327 | 시간 2020[s] | 퍼플렉서티 117.07
# | 에폭 3 |  반복 1301 / 1327 | 시간 2053[s] | 퍼플렉서티 148.15
# | 에폭 3 |  반복 1321 / 1327 | 시간 2086[s] | 퍼플렉서티 145.04
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티: 124.22405880389114
# --------------------------------------------------
# | 에폭 4 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 198.99
# | 에폭 4 |  반복 21 / 1327 | 시간 33[s] | 퍼플렉서티 130.55
# | 에폭 4 |  반복 41 / 1327 | 시간 66[s] | 퍼플렉서티 124.40
# | 에폭 4 |  반복 61 / 1327 | 시간 98[s] | 퍼플렉서티 118.66
# | 에폭 4 |  반복 81 / 1327 | 시간 131[s] | 퍼플렉서티 104.03
# | 에폭 4 |  반복 101 / 1327 | 시간 163[s] | 퍼플렉서티 100.31
# | 에폭 4 |  반복 121 / 1327 | 시간 195[s] | 퍼플렉서티 110.30
# | 에폭 4 |  반복 141 / 1327 | 시간 228[s] | 퍼플렉서티 120.02
# | 에폭 4 |  반복 161 / 1327 | 시간 259[s] | 퍼플렉서티 134.99
# | 에폭 4 |  반복 181 / 1327 | 시간 291[s] | 퍼플렉서티 144.15
# | 에폭 4 |  반복 201 / 1327 | 시간 324[s] | 퍼플렉서티 136.68
# | 에폭 4 |  반복 221 / 1327 | 시간 357[s] | 퍼플렉서티 134.34
# | 에폭 4 |  반복 241 / 1327 | 시간 388[s] | 퍼플렉서티 128.25
# | 에폭 4 |  반복 261 / 1327 | 시간 420[s] | 퍼플렉서티 137.16
# | 에폭 4 |  반복 281 / 1327 | 시간 453[s] | 퍼플렉서티 133.94
# | 에폭 4 |  반복 301 / 1327 | 시간 486[s] | 퍼플렉서티 116.44
# | 에폭 4 |  반복 321 / 1327 | 시간 519[s] | 퍼플렉서티 90.28
# | 에폭 4 |  반복 341 / 1327 | 시간 551[s] | 퍼플렉서티 127.31
# | 에폭 4 |  반복 361 / 1327 | 시간 584[s] | 퍼플렉서티 137.61
# | 에폭 4 |  반복 381 / 1327 | 시간 617[s] | 퍼플렉서티 111.40
# | 에폭 4 |  반복 401 / 1327 | 시간 650[s] | 퍼플렉서티 128.30
# | 에폭 4 |  반복 421 / 1327 | 시간 682[s] | 퍼플렉서티 108.96
# | 에폭 4 |  반복 441 / 1327 | 시간 714[s] | 퍼플렉서티 120.47
# | 에폭 4 |  반복 461 / 1327 | 시간 746[s] | 퍼플렉서티 116.94
# | 에폭 4 |  반복 481 / 1327 | 시간 778[s] | 퍼플렉서티 115.10
# | 에폭 4 |  반복 501 / 1327 | 시간 810[s] | 퍼플렉서티 128.86
# | 에폭 4 |  반복 521 / 1327 | 시간 842[s] | 퍼플렉서티 130.88
# | 에폭 4 |  반복 541 / 1327 | 시간 874[s] | 퍼플렉서티 135.24
# | 에폭 4 |  반복 561 / 1327 | 시간 906[s] | 퍼플렉서티 113.88
# | 에폭 4 |  반복 581 / 1327 | 시간 939[s] | 퍼플렉서티 103.07
# | 에폭 4 |  반복 601 / 1327 | 시간 972[s] | 퍼플렉서티 146.11
# | 에폭 4 |  반복 621 / 1327 | 시간 1004[s] | 퍼플렉서티 136.34
# | 에폭 4 |  반복 641 / 1327 | 시간 1036[s] | 퍼플렉서티 123.33
# | 에폭 4 |  반복 661 / 1327 | 시간 1068[s] | 퍼플렉서티 115.42
# | 에폭 4 |  반복 681 / 1327 | 시간 1102[s] | 퍼플렉서티 100.80
# | 에폭 4 |  반복 701 / 1327 | 시간 1134[s] | 퍼플렉서티 117.48
# | 에폭 4 |  반복 721 / 1327 | 시간 1166[s] | 퍼플렉서티 121.33
# | 에폭 4 |  반복 741 / 1327 | 시간 1198[s] | 퍼플렉서티 103.70
# | 에폭 4 |  반복 761 / 1327 | 시간 1230[s] | 퍼플렉서티 96.29
# | 에폭 4 |  반복 781 / 1327 | 시간 1264[s] | 퍼플렉서티 103.95
# | 에폭 4 |  반복 801 / 1327 | 시간 1295[s] | 퍼플렉서티 118.11
# | 에폭 4 |  반복 821 / 1327 | 시간 1326[s] | 퍼플렉서티 115.32
# | 에폭 4 |  반복 841 / 1327 | 시간 1357[s] | 퍼플렉서티 114.87
# | 에폭 4 |  반복 861 / 1327 | 시간 1388[s] | 퍼플렉서티 112.89
# | 에폭 4 |  반복 881 / 1327 | 시간 1419[s] | 퍼플렉서티 104.46
# | 에폭 4 |  반복 901 / 1327 | 시간 1451[s] | 퍼플렉서티 132.91
# | 에폭 4 |  반복 921 / 1327 | 시간 1482[s] | 퍼플렉서티 115.61
# | 에폭 4 |  반복 941 / 1327 | 시간 1513[s] | 퍼플렉서티 122.66
# | 에폭 4 |  반복 961 / 1327 | 시간 1544[s] | 퍼플렉서티 132.58
# | 에폭 4 |  반복 981 / 1327 | 시간 1576[s] | 퍼플렉서티 126.14
# | 에폭 4 |  반복 1001 / 1327 | 시간 1607[s] | 퍼플렉서티 107.75
# | 에폭 4 |  반복 1021 / 1327 | 시간 1638[s] | 퍼플렉서티 128.93
# | 에폭 4 |  반복 1041 / 1327 | 시간 1670[s] | 퍼플렉서티 111.62
# | 에폭 4 |  반복 1061 / 1327 | 시간 1701[s] | 퍼플렉서티 106.73
# | 에폭 4 |  반복 1081 / 1327 | 시간 1732[s] | 퍼플렉서티 87.17
# | 에폭 4 |  반복 1101 / 1327 | 시간 1763[s] | 퍼플렉서티 90.60
# | 에폭 4 |  반복 1121 / 1327 | 시간 1794[s] | 퍼플렉서티 122.39
# | 에폭 4 |  반복 1141 / 1327 | 시간 1825[s] | 퍼플렉서티 116.71
# | 에폭 4 |  반복 1161 / 1327 | 시간 1858[s] | 퍼플렉서티 100.38
# | 에폭 4 |  반복 1181 / 1327 | 시간 1890[s] | 퍼플렉서티 108.08
# | 에폭 4 |  반복 1201 / 1327 | 시간 1921[s] | 퍼플렉서티 90.50
# | 에폭 4 |  반복 1221 / 1327 | 시간 1952[s] | 퍼플렉서티 89.91
# | 에폭 4 |  반복 1241 / 1327 | 시간 1984[s] | 퍼플렉서티 106.53
# | 에폭 4 |  반복 1261 / 1327 | 시간 2015[s] | 퍼플렉서티 102.35
# | 에폭 4 |  반복 1281 / 1327 | 시간 2047[s] | 퍼플렉서티 101.19
# | 에폭 4 |  반복 1301 / 1327 | 시간 2078[s] | 퍼플렉서티 128.96
# | 에폭 4 |  반복 1321 / 1327 | 시간 2110[s] | 퍼플렉서티 128.27
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티: 111.91117858050612
# --------------------------------------------------
# | 에폭 5 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 178.22
# | 에폭 5 |  반복 21 / 1327 | 시간 32[s] | 퍼플렉서티 112.15
# | 에폭 5 |  반복 41 / 1327 | 시간 64[s] | 퍼플렉서티 109.28
# | 에폭 5 |  반복 61 / 1327 | 시간 96[s] | 퍼플렉서티 103.61
# | 에폭 5 |  반복 81 / 1327 | 시간 127[s] | 퍼플렉서티 90.20
# | 에폭 5 |  반복 101 / 1327 | 시간 159[s] | 퍼플렉서티 87.72
# | 에폭 5 |  반복 121 / 1327 | 시간 191[s] | 퍼플렉서티 97.16
# | 에폭 5 |  반복 141 / 1327 | 시간 223[s] | 퍼플렉서티 104.84
# | 에폭 5 |  반복 161 / 1327 | 시간 254[s] | 퍼플렉서티 120.52
# | 에폭 5 |  반복 181 / 1327 | 시간 285[s] | 퍼플렉서티 126.56
# | 에폭 5 |  반복 201 / 1327 | 시간 316[s] | 퍼플렉서티 123.73
# | 에폭 5 |  반복 221 / 1327 | 시간 348[s] | 퍼플렉서티 120.74
# | 에폭 5 |  반복 241 / 1327 | 시간 379[s] | 퍼플렉서티 114.06
# | 에폭 5 |  반복 261 / 1327 | 시간 410[s] | 퍼플렉서티 121.50
# | 에폭 5 |  반복 281 / 1327 | 시간 442[s] | 퍼플렉서티 118.86
# | 에폭 5 |  반복 301 / 1327 | 시간 473[s] | 퍼플렉서티 99.80
# | 에폭 5 |  반복 321 / 1327 | 시간 505[s] | 퍼플렉서티 79.20
# | 에폭 5 |  반복 341 / 1327 | 시간 537[s] | 퍼플렉서티 115.35
# | 에폭 5 |  반복 361 / 1327 | 시간 569[s] | 퍼플렉서티 122.18
# | 에폭 5 |  반복 381 / 1327 | 시간 600[s] | 퍼플렉서티 98.75
# | 에폭 5 |  반복 401 / 1327 | 시간 631[s] | 퍼플렉서티 113.11
# | 에폭 5 |  반복 421 / 1327 | 시간 662[s] | 퍼플렉서티 96.60
# | 에폭 5 |  반복 441 / 1327 | 시간 693[s] | 퍼플렉서티 105.94
# | 에폭 5 |  반복 461 / 1327 | 시간 724[s] | 퍼플렉서티 103.83
# | 에폭 5 |  반복 481 / 1327 | 시간 755[s] | 퍼플렉서티 103.50
# | 에폭 5 |  반복 501 / 1327 | 시간 786[s] | 퍼플렉서티 115.57
# | 에폭 5 |  반복 521 / 1327 | 시간 817[s] | 퍼플렉서티 117.63
# | 에폭 5 |  반복 541 / 1327 | 시간 849[s] | 퍼플렉서티 121.41
# | 에폭 5 |  반복 561 / 1327 | 시간 880[s] | 퍼플렉서티 100.58
# | 에폭 5 |  반복 581 / 1327 | 시간 911[s] | 퍼플렉서티 92.47
# | 에폭 5 |  반복 601 / 1327 | 시간 943[s] | 퍼플렉서티 130.09
# | 에폭 5 |  반복 621 / 1327 | 시간 974[s] | 퍼플렉서티 123.43
# | 에폭 5 |  반복 641 / 1327 | 시간 1005[s] | 퍼플렉서티 111.02
# | 에폭 5 |  반복 661 / 1327 | 시간 1036[s] | 퍼플렉서티 103.20
# | 에폭 5 |  반복 681 / 1327 | 시간 1067[s] | 퍼플렉서티 90.15
# | 에폭 5 |  반복 701 / 1327 | 시간 1098[s] | 퍼플렉서티 104.66
# | 에폭 5 |  반복 721 / 1327 | 시간 1130[s] | 퍼플렉서티 108.92
# | 에폭 5 |  반복 741 / 1327 | 시간 1161[s] | 퍼플렉서티 93.74
# | 에폭 5 |  반복 761 / 1327 | 시간 1192[s] | 퍼플렉서티 85.56
# | 에폭 5 |  반복 781 / 1327 | 시간 1223[s] | 퍼플렉서티 92.65
# | 에폭 5 |  반복 801 / 1327 | 시간 1254[s] | 퍼플렉서티 107.11
# | 에폭 5 |  반복 821 / 1327 | 시간 1284[s] | 퍼플렉서티 105.00
# | 에폭 5 |  반복 841 / 1327 | 시간 1315[s] | 퍼플렉서티 104.01
# | 에폭 5 |  반복 861 / 1327 | 시간 1345[s] | 퍼플렉서티 103.13
# | 에폭 5 |  반복 881 / 1327 | 시간 1376[s] | 퍼플렉서티 94.19
# | 에폭 5 |  반복 901 / 1327 | 시간 1406[s] | 퍼플렉서티 118.82
# | 에폭 5 |  반복 921 / 1327 | 시간 1437[s] | 퍼플렉서티 105.73
# | 에폭 5 |  반복 941 / 1327 | 시간 1468[s] | 퍼플렉서티 111.07
# | 에폭 5 |  반복 961 / 1327 | 시간 1499[s] | 퍼플렉서티 121.56
# | 에폭 5 |  반복 981 / 1327 | 시간 1529[s] | 퍼플렉서티 114.66
# | 에폭 5 |  반복 1001 / 1327 | 시간 1560[s] | 퍼플렉서티 97.85
# | 에폭 5 |  반복 1021 / 1327 | 시간 1591[s] | 퍼플렉서티 115.89
# | 에폭 5 |  반복 1041 / 1327 | 시간 1621[s] | 퍼플렉서티 101.36
# | 에폭 5 |  반복 1061 / 1327 | 시간 1652[s] | 퍼플렉서티 95.16
# | 에폭 5 |  반복 1081 / 1327 | 시간 1683[s] | 퍼플렉서티 78.97
# | 에폭 5 |  반복 1101 / 1327 | 시간 1714[s] | 퍼플렉서티 81.72
# | 에폭 5 |  반복 1121 / 1327 | 시간 1745[s] | 퍼플렉서티 111.08
# | 에폭 5 |  반복 1141 / 1327 | 시간 1777[s] | 퍼플렉서티 107.05
# | 에폭 5 |  반복 1161 / 1327 | 시간 1807[s] | 퍼플렉서티 90.10
# | 에폭 5 |  반복 1181 / 1327 | 시간 1837[s] | 퍼플렉서티 98.10
# | 에폭 5 |  반복 1201 / 1327 | 시간 1867[s] | 퍼플렉서티 81.42
# | 에폭 5 |  반복 1221 / 1327 | 시간 1897[s] | 퍼플렉서티 81.91
# | 에폭 5 |  반복 1241 / 1327 | 시간 1927[s] | 퍼플렉서티 98.99
# | 에폭 5 |  반복 1261 / 1327 | 시간 1957[s] | 퍼플렉서티 92.76
# | 에폭 5 |  반복 1281 / 1327 | 시간 1988[s] | 퍼플렉서티 92.76
# | 에폭 5 |  반복 1301 / 1327 | 시간 2017[s] | 퍼플렉서티 118.21
# | 에폭 5 |  반복 1321 / 1327 | 시간 2048[s] | 퍼플렉서티 115.19
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티: 104.72927741661331
# --------------------------------------------------
