# %%
class Embedding:
    def __init__(self, w):
        self.params = [w]
        self.grads = [np.zeros_like(w)]
        self.idx = None
    
    def forward(self, idx):
        w, = self.params
        self.idx = idx
        out = w[idx]
        return out
    
    def backward(self, dout):
        dw, = self.grads
        dw[...] = 0
        
        for i, word_id in enumerate(self.idx):
            dw[word_id]  += dout[i]
        
        return None

# %%
class EmbeddingDot:
    def __init__(self, w):
        self.embed = Embedding(w)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None
        
    def forward(self, h, idx):
        target_w = self.embed.forward(idx)
        out = np.sum(target_w * h, axis=1)
        
        self.cache = (h, target_w)
        return out
    
    def backward(self, dout):
        h, target_w = self.cache
        dout = dout.reshape(dout.shape[0], 1)
        
        dtarget_w = dout * h
        self.embed.backward(dtarget_w)
        dh = dout * target_w
        return dh

# %%
import numpy as np

np.random.choice(10)
# Out:
# 0

# %%
np.random.choice(10)
# Out:
# 2

# %%
p = [0.7, 0.29, 0.01]
new_p = np.power(p, 0.75)
new_p /= np.sum(new_p)
print(new_p)
# Out:
# [0.64196878 0.33150408 0.02652714]

# %%
from negative_sampling_layer import UnigramSampler

corpus = np.array([0,1,2,3,4,1,2,3])
power = 0.75
sample_size = 2

sampler = UnigramSampler(corpus, power, sample_size)
target = np.array([1,3,0])
negative_sample = sampler.get_negative_sample(target)
print(negative_sample)
# Out:
# [[3 0]
#  [0 4]
#  [3 1]]

# %%
class NegativeSamplingLoss:
    def __init__(self, w, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(w) for _ in range(sample_size + 1)]
        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads
            
    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)
        
        # 긍정적 예 순전파
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)
        
        # 부정적 예 순전파
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)
            
        return loss
    
    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = lo.backward(dout)
            dh += l1.backward(dscore)
            
        return dh

# %%
from common.layers import Embedding
from negative_sampling_layer import NegativeSamplingLoss

class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        v, h = vocab_size, hidden_size
        
        # 가중치 초기화
        w_in = 0.01 * np.random.randn(v, h).astype('f')
        w_out = 0.01 * np.random.randn(h, v).astype('f')
        
        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(w_in)
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(w_out, corpus, power=0.75, sample_size=5)
        
        # 모든 가중치와 기울기를 배열에 모은다
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads
            
        # 인스턴스 변수에 단어의 분산 표현을 저장한다
        self.word_vecs = w_in
        
    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss
    
    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %%
import sys
sys.path.append('..')
from common import config
config.GPU = True
import pickle
import numpy as np
from common.trainer import Trainer
from common.optimizer import Adam
from cbow import CBOW
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb

# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 1

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)
    
# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 1[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 9295 | 시간 1[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 9295 | 시간 1[s] | 손실 4.05
# | 에폭 1 |  반복 101 / 9295 | 시간 2[s] | 손실 3.92
# | 에폭 1 |  반복 121 / 9295 | 시간 2[s] | 손실 3.77
# | 에폭 1 |  반복 141 / 9295 | 시간 2[s] | 손실 3.62
# | 에폭 1 |  반복 161 / 9295 | 시간 3[s] | 손실 3.49
# | 에폭 1 |  반복 181 / 9295 | 시간 3[s] | 손실 3.36
# | 에폭 1 |  반복 201 / 9295 | 시간 4[s] | 손실 3.24
# | 에폭 1 |  반복 221 / 9295 | 시간 4[s] | 손실 3.16
# | 에폭 1 |  반복 241 / 9295 | 시간 4[s] | 손실 3.10
# | 에폭 1 |  반복 261 / 9295 | 시간 5[s] | 손실 3.03
# | 에폭 1 |  반복 281 / 9295 | 시간 5[s] | 손실 2.97
# | 에폭 1 |  반복 301 / 9295 | 시간 5[s] | 손실 2.94
# | 에폭 1 |  반복 321 / 9295 | 시간 6[s] | 손실 2.88
# | 에폭 1 |  반복 341 / 9295 | 시간 6[s] | 손실 2.86
# | 에폭 1 |  반복 361 / 9295 | 시간 7[s] | 손실 2.84
# | 에폭 1 |  반복 381 / 9295 | 시간 7[s] | 손실 2.80
# | 에폭 1 |  반복 401 / 9295 | 시간 7[s] | 손실 2.77
# | 에폭 1 |  반복 421 / 9295 | 시간 8[s] | 손실 2.77
# | 에폭 1 |  반복 441 / 9295 | 시간 8[s] | 손실 2.75
# | 에폭 1 |  반복 461 / 9295 | 시간 9[s] | 손실 2.72
# | 에폭 1 |  반복 481 / 9295 | 시간 9[s] | 손실 2.70
# | 에폭 1 |  반복 501 / 9295 | 시간 9[s] | 손실 2.69
# | 에폭 1 |  반복 521 / 9295 | 시간 10[s] | 손실 2.69
# | 에폭 1 |  반복 541 / 9295 | 시간 10[s] | 손실 2.68
# | 에폭 1 |  반복 561 / 9295 | 시간 10[s] | 손실 2.69
# | 에폭 1 |  반복 581 / 9295 | 시간 11[s] | 손실 2.66
# | 에폭 1 |  반복 601 / 9295 | 시간 11[s] | 손실 2.67
# | 에폭 1 |  반복 621 / 9295 | 시간 12[s] | 손실 2.65
# | 에폭 1 |  반복 641 / 9295 | 시간 12[s] | 손실 2.66
# | 에폭 1 |  반복 661 / 9295 | 시간 12[s] | 손실 2.66
# | 에폭 1 |  반복 681 / 9295 | 시간 13[s] | 손실 2.62
# | 에폭 1 |  반복 701 / 9295 | 시간 13[s] | 손실 2.64
# | 에폭 1 |  반복 721 / 9295 | 시간 13[s] | 손실 2.63
# | 에폭 1 |  반복 741 / 9295 | 시간 14[s] | 손실 2.62
# | 에폭 1 |  반복 761 / 9295 | 시간 14[s] | 손실 2.63
# | 에폭 1 |  반복 781 / 9295 | 시간 15[s] | 손실 2.63
# | 에폭 1 |  반복 801 / 9295 | 시간 15[s] | 손실 2.60
# | 에폭 1 |  반복 821 / 9295 | 시간 15[s] | 손실 2.60
# | 에폭 1 |  반복 841 / 9295 | 시간 16[s] | 손실 2.60
# | 에폭 1 |  반복 861 / 9295 | 시간 16[s] | 손실 2.59
# | 에폭 1 |  반복 881 / 9295 | 시간 17[s] | 손실 2.56
# | 에폭 1 |  반복 901 / 9295 | 시간 17[s] | 손실 2.59
# | 에폭 1 |  반복 921 / 9295 | 시간 17[s] | 손실 2.60
# | 에폭 1 |  반복 941 / 9295 | 시간 18[s] | 손실 2.56
# | 에폭 1 |  반복 961 / 9295 | 시간 18[s] | 손실 2.60
# | 에폭 1 |  반복 981 / 9295 | 시간 19[s] | 손실 2.60
# | 에폭 1 |  반복 1001 / 9295 | 시간 19[s] | 손실 2.59
# | 에폭 1 |  반복 1021 / 9295 | 시간 19[s] | 손실 2.56
# | 에폭 1 |  반복 1041 / 9295 | 시간 20[s] | 손실 2.58
# | 에폭 1 |  반복 1061 / 9295 | 시간 20[s] | 손실 2.59
# | 에폭 1 |  반복 1081 / 9295 | 시간 20[s] | 손실 2.56
# | 에폭 1 |  반복 1101 / 9295 | 시간 21[s] | 손실 2.58
# | 에폭 1 |  반복 1121 / 9295 | 시간 21[s] | 손실 2.55
# | 에폭 1 |  반복 1141 / 9295 | 시간 22[s] | 손실 2.60
# | 에폭 1 |  반복 1161 / 9295 | 시간 22[s] | 손실 2.56
# | 에폭 1 |  반복 1181 / 9295 | 시간 22[s] | 손실 2.53
# | 에폭 1 |  반복 1201 / 9295 | 시간 23[s] | 손실 2.55
# | 에폭 1 |  반복 1221 / 9295 | 시간 23[s] | 손실 2.55
# | 에폭 1 |  반복 1241 / 9295 | 시간 24[s] | 손실 2.52
# | 에폭 1 |  반복 1261 / 9295 | 시간 24[s] | 손실 2.55
# | 에폭 1 |  반복 1281 / 9295 | 시간 24[s] | 손실 2.54
# | 에폭 1 |  반복 1301 / 9295 | 시간 25[s] | 손실 2.54
# | 에폭 1 |  반복 1321 / 9295 | 시간 25[s] | 손실 2.55
# | 에폭 1 |  반복 1341 / 9295 | 시간 26[s] | 손실 2.54
# | 에폭 1 |  반복 1361 / 9295 | 시간 26[s] | 손실 2.53
# | 에폭 1 |  반복 1381 / 9295 | 시간 26[s] | 손실 2.52
# | 에폭 1 |  반복 1401 / 9295 | 시간 27[s] | 손실 2.52
# | 에폭 1 |  반복 1421 / 9295 | 시간 27[s] | 손실 2.52
# | 에폭 1 |  반복 1441 / 9295 | 시간 28[s] | 손실 2.55
# | 에폭 1 |  반복 1461 / 9295 | 시간 28[s] | 손실 2.54
# | 에폭 1 |  반복 1481 / 9295 | 시간 29[s] | 손실 2.52
# | 에폭 1 |  반복 1501 / 9295 | 시간 29[s] | 손실 2.50
# | 에폭 1 |  반복 1521 / 9295 | 시간 30[s] | 손실 2.54
# | 에폭 1 |  반복 1541 / 9295 | 시간 30[s] | 손실 2.52
# | 에폭 1 |  반복 1561 / 9295 | 시간 30[s] | 손실 2.53
# | 에폭 1 |  반복 1581 / 9295 | 시간 31[s] | 손실 2.52
# | 에폭 1 |  반복 1601 / 9295 | 시간 31[s] | 손실 2.54
# | 에폭 1 |  반복 1621 / 9295 | 시간 32[s] | 손실 2.53
# | 에폭 1 |  반복 1641 / 9295 | 시간 32[s] | 손실 2.52
# | 에폭 1 |  반복 1661 / 9295 | 시간 32[s] | 손실 2.52
# | 에폭 1 |  반복 1681 / 9295 | 시간 33[s] | 손실 2.51
# | 에폭 1 |  반복 1701 / 9295 | 시간 33[s] | 손실 2.53
# | 에폭 1 |  반복 1721 / 9295 | 시간 34[s] | 손실 2.51
# | 에폭 1 |  반복 1741 / 9295 | 시간 34[s] | 손실 2.52
# | 에폭 1 |  반복 1761 / 9295 | 시간 34[s] | 손실 2.48
# | 에폭 1 |  반복 1781 / 9295 | 시간 35[s] | 손실 2.52
# | 에폭 1 |  반복 1801 / 9295 | 시간 35[s] | 손실 2.52
# | 에폭 1 |  반복 1821 / 9295 | 시간 36[s] | 손실 2.49
# | 에폭 1 |  반복 1841 / 9295 | 시간 36[s] | 손실 2.53
# | 에폭 1 |  반복 1861 / 9295 | 시간 37[s] | 손실 2.49
# | 에폭 1 |  반복 1881 / 9295 | 시간 37[s] | 손실 2.52
# | 에폭 1 |  반복 1901 / 9295 | 시간 37[s] | 손실 2.50
# | 에폭 1 |  반복 1921 / 9295 | 시간 38[s] | 손실 2.49
# | 에폭 1 |  반복 1941 / 9295 | 시간 38[s] | 손실 2.51
# | 에폭 1 |  반복 1961 / 9295 | 시간 39[s] | 손실 2.49
# | 에폭 1 |  반복 1981 / 9295 | 시간 39[s] | 손실 2.50
# | 에폭 1 |  반복 2001 / 9295 | 시간 40[s] | 손실 2.50
# | 에폭 1 |  반복 2021 / 9295 | 시간 40[s] | 손실 2.51
# | 에폭 1 |  반복 2041 / 9295 | 시간 40[s] | 손실 2.48
# | 에폭 1 |  반복 2061 / 9295 | 시간 41[s] | 손실 2.52
# | 에폭 1 |  반복 2081 / 9295 | 시간 41[s] | 손실 2.50
# | 에폭 1 |  반복 2101 / 9295 | 시간 42[s] | 손실 2.50
# | 에폭 1 |  반복 2121 / 9295 | 시간 42[s] | 손실 2.53
# | 에폭 1 |  반복 2141 / 9295 | 시간 42[s] | 손실 2.47
# | 에폭 1 |  반복 2161 / 9295 | 시간 43[s] | 손실 2.48
# | 에폭 1 |  반복 2181 / 9295 | 시간 43[s] | 손실 2.49
# | 에폭 1 |  반복 2201 / 9295 | 시간 44[s] | 손실 2.49
# | 에폭 1 |  반복 2221 / 9295 | 시간 44[s] | 손실 2.50
# | 에폭 1 |  반복 2241 / 9295 | 시간 45[s] | 손실 2.50
# | 에폭 1 |  반복 2261 / 9295 | 시간 45[s] | 손실 2.51
# | 에폭 1 |  반복 2281 / 9295 | 시간 45[s] | 손실 2.50
# | 에폭 1 |  반복 2301 / 9295 | 시간 46[s] | 손실 2.52
# | 에폭 1 |  반복 2321 / 9295 | 시간 46[s] | 손실 2.49
# | 에폭 1 |  반복 2341 / 9295 | 시간 47[s] | 손실 2.50
# | 에폭 1 |  반복 2361 / 9295 | 시간 47[s] | 손실 2.49
# | 에폭 1 |  반복 2381 / 9295 | 시간 48[s] | 손실 2.49
# | 에폭 1 |  반복 2401 / 9295 | 시간 48[s] | 손실 2.48
# | 에폭 1 |  반복 2421 / 9295 | 시간 48[s] | 손실 2.48
# | 에폭 1 |  반복 2441 / 9295 | 시간 49[s] | 손실 2.49
# | 에폭 1 |  반복 2461 / 9295 | 시간 49[s] | 손실 2.48
# | 에폭 1 |  반복 2481 / 9295 | 시간 50[s] | 손실 2.49
# | 에폭 1 |  반복 2501 / 9295 | 시간 50[s] | 손실 2.48
# | 에폭 1 |  반복 2521 / 9295 | 시간 51[s] | 손실 2.49
# | 에폭 1 |  반복 2541 / 9295 | 시간 51[s] | 손실 2.45
# | 에폭 1 |  반복 2561 / 9295 | 시간 51[s] | 손실 2.48
# | 에폭 1 |  반복 2581 / 9295 | 시간 52[s] | 손실 2.47
# | 에폭 1 |  반복 2601 / 9295 | 시간 52[s] | 손실 2.52
# | 에폭 1 |  반복 2621 / 9295 | 시간 53[s] | 손실 2.50
# | 에폭 1 |  반복 2641 / 9295 | 시간 53[s] | 손실 2.49
# | 에폭 1 |  반복 2661 / 9295 | 시간 53[s] | 손실 2.47
# | 에폭 1 |  반복 2681 / 9295 | 시간 54[s] | 손실 2.47
# | 에폭 1 |  반복 2701 / 9295 | 시간 54[s] | 손실 2.49
# | 에폭 1 |  반복 2721 / 9295 | 시간 55[s] | 손실 2.49
# | 에폭 1 |  반복 2741 / 9295 | 시간 55[s] | 손실 2.50
# | 에폭 1 |  반복 2761 / 9295 | 시간 56[s] | 손실 2.49
# | 에폭 1 |  반복 2781 / 9295 | 시간 56[s] | 손실 2.45
# | 에폭 1 |  반복 2801 / 9295 | 시간 56[s] | 손실 2.47
# | 에폭 1 |  반복 2821 / 9295 | 시간 57[s] | 손실 2.47
# | 에폭 1 |  반복 2841 / 9295 | 시간 57[s] | 손실 2.46
# | 에폭 1 |  반복 2861 / 9295 | 시간 58[s] | 손실 2.48
# | 에폭 1 |  반복 2881 / 9295 | 시간 58[s] | 손실 2.48
# | 에폭 1 |  반복 2901 / 9295 | 시간 58[s] | 손실 2.46
# | 에폭 1 |  반복 2921 / 9295 | 시간 59[s] | 손실 2.46
# | 에폭 1 |  반복 2941 / 9295 | 시간 59[s] | 손실 2.46
# | 에폭 1 |  반복 2961 / 9295 | 시간 60[s] | 손실 2.49
# | 에폭 1 |  반복 2981 / 9295 | 시간 60[s] | 손실 2.46
# | 에폭 1 |  반복 3001 / 9295 | 시간 60[s] | 손실 2.43
# | 에폭 1 |  반복 3021 / 9295 | 시간 61[s] | 손실 2.46
# | 에폭 1 |  반복 3041 / 9295 | 시간 61[s] | 손실 2.44
# | 에폭 1 |  반복 3061 / 9295 | 시간 62[s] | 손실 2.45
# | 에폭 1 |  반복 3081 / 9295 | 시간 62[s] | 손실 2.43
# | 에폭 1 |  반복 3101 / 9295 | 시간 63[s] | 손실 2.48
# | 에폭 1 |  반복 3121 / 9295 | 시간 63[s] | 손실 2.46
# | 에폭 1 |  반복 3141 / 9295 | 시간 63[s] | 손실 2.48
# | 에폭 1 |  반복 3161 / 9295 | 시간 64[s] | 손실 2.47
# | 에폭 1 |  반복 3181 / 9295 | 시간 64[s] | 손실 2.51
# | 에폭 1 |  반복 3201 / 9295 | 시간 65[s] | 손실 2.44
# | 에폭 1 |  반복 3221 / 9295 | 시간 65[s] | 손실 2.47
# | 에폭 1 |  반복 3241 / 9295 | 시간 65[s] | 손실 2.44
# | 에폭 1 |  반복 3261 / 9295 | 시간 66[s] | 손실 2.44
# | 에폭 1 |  반복 3281 / 9295 | 시간 66[s] | 손실 2.42
# | 에폭 1 |  반복 3301 / 9295 | 시간 67[s] | 손실 2.47
# | 에폭 1 |  반복 3321 / 9295 | 시간 67[s] | 손실 2.44
# | 에폭 1 |  반복 3341 / 9295 | 시간 67[s] | 손실 2.45
# | 에폭 1 |  반복 3361 / 9295 | 시간 68[s] | 손실 2.46
# | 에폭 1 |  반복 3381 / 9295 | 시간 68[s] | 손실 2.48
# | 에폭 1 |  반복 3401 / 9295 | 시간 69[s] | 손실 2.46
# | 에폭 1 |  반복 3421 / 9295 | 시간 69[s] | 손실 2.44
# | 에폭 1 |  반복 3441 / 9295 | 시간 70[s] | 손실 2.43
# | 에폭 1 |  반복 3461 / 9295 | 시간 70[s] | 손실 2.43
# | 에폭 1 |  반복 3481 / 9295 | 시간 70[s] | 손실 2.47
# | 에폭 1 |  반복 3501 / 9295 | 시간 71[s] | 손실 2.46
# | 에폭 1 |  반복 3521 / 9295 | 시간 71[s] | 손실 2.42
# | 에폭 1 |  반복 3541 / 9295 | 시간 72[s] | 손실 2.43
# | 에폭 1 |  반복 3561 / 9295 | 시간 72[s] | 손실 2.43
# | 에폭 1 |  반복 3581 / 9295 | 시간 73[s] | 손실 2.42
# | 에폭 1 |  반복 3601 / 9295 | 시간 73[s] | 손실 2.43
# | 에폭 1 |  반복 3621 / 9295 | 시간 74[s] | 손실 2.45
# | 에폭 1 |  반복 3641 / 9295 | 시간 74[s] | 손실 2.43
# | 에폭 1 |  반복 3661 / 9295 | 시간 74[s] | 손실 2.41
# | 에폭 1 |  반복 3681 / 9295 | 시간 75[s] | 손실 2.43
# | 에폭 1 |  반복 3701 / 9295 | 시간 75[s] | 손실 2.45
# | 에폭 1 |  반복 3721 / 9295 | 시간 76[s] | 손실 2.45
# | 에폭 1 |  반복 3741 / 9295 | 시간 76[s] | 손실 2.44
# | 에폭 1 |  반복 3761 / 9295 | 시간 76[s] | 손실 2.42
# | 에폭 1 |  반복 3781 / 9295 | 시간 77[s] | 손실 2.44
# | 에폭 1 |  반복 3801 / 9295 | 시간 77[s] | 손실 2.41
# | 에폭 1 |  반복 3821 / 9295 | 시간 78[s] | 손실 2.42
# | 에폭 1 |  반복 3841 / 9295 | 시간 78[s] | 손실 2.42
# | 에폭 1 |  반복 3861 / 9295 | 시간 79[s] | 손실 2.41
# | 에폭 1 |  반복 3881 / 9295 | 시간 79[s] | 손실 2.42
# | 에폭 1 |  반복 3901 / 9295 | 시간 79[s] | 손실 2.41
# | 에폭 1 |  반복 3921 / 9295 | 시간 80[s] | 손실 2.45
# | 에폭 1 |  반복 3941 / 9295 | 시간 80[s] | 손실 2.39
# | 에폭 1 |  반복 3961 / 9295 | 시간 81[s] | 손실 2.41
# | 에폭 1 |  반복 3981 / 9295 | 시간 81[s] | 손실 2.44
# | 에폭 1 |  반복 4001 / 9295 | 시간 81[s] | 손실 2.43
# | 에폭 1 |  반복 4021 / 9295 | 시간 82[s] | 손실 2.42
# | 에폭 1 |  반복 4041 / 9295 | 시간 82[s] | 손실 2.41
# | 에폭 1 |  반복 4061 / 9295 | 시간 83[s] | 손실 2.40
# | 에폭 1 |  반복 4081 / 9295 | 시간 83[s] | 손실 2.42
# | 에폭 1 |  반복 4101 / 9295 | 시간 83[s] | 손실 2.42
# | 에폭 1 |  반복 4121 / 9295 | 시간 84[s] | 손실 2.40
# | 에폭 1 |  반복 4141 / 9295 | 시간 84[s] | 손실 2.40
# | 에폭 1 |  반복 4161 / 9295 | 시간 85[s] | 손실 2.41
# | 에폭 1 |  반복 4181 / 9295 | 시간 85[s] | 손실 2.38
# | 에폭 1 |  반복 4201 / 9295 | 시간 86[s] | 손실 2.39
# | 에폭 1 |  반복 4221 / 9295 | 시간 86[s] | 손실 2.41
# | 에폭 1 |  반복 4241 / 9295 | 시간 87[s] | 손실 2.37
# | 에폭 1 |  반복 4261 / 9295 | 시간 87[s] | 손실 2.39
# | 에폭 1 |  반복 4281 / 9295 | 시간 88[s] | 손실 2.38
# | 에폭 1 |  반복 4301 / 9295 | 시간 88[s] | 손실 2.41
# | 에폭 1 |  반복 4321 / 9295 | 시간 88[s] | 손실 2.36
# | 에폭 1 |  반복 4341 / 9295 | 시간 89[s] | 손실 2.42
# | 에폭 1 |  반복 4361 / 9295 | 시간 89[s] | 손실 2.39
# | 에폭 1 |  반복 4381 / 9295 | 시간 90[s] | 손실 2.39
# | 에폭 1 |  반복 4401 / 9295 | 시간 90[s] | 손실 2.42
# | 에폭 1 |  반복 4421 / 9295 | 시간 90[s] | 손실 2.38
# | 에폭 1 |  반복 4441 / 9295 | 시간 91[s] | 손실 2.37
# | 에폭 1 |  반복 4461 / 9295 | 시간 91[s] | 손실 2.39
# | 에폭 1 |  반복 4481 / 9295 | 시간 92[s] | 손실 2.35
# | 에폭 1 |  반복 4501 / 9295 | 시간 92[s] | 손실 2.38
# | 에폭 1 |  반복 4521 / 9295 | 시간 92[s] | 손실 2.36
# | 에폭 1 |  반복 4541 / 9295 | 시간 93[s] | 손실 2.37
# | 에폭 1 |  반복 4561 / 9295 | 시간 93[s] | 손실 2.40
# | 에폭 1 |  반복 4581 / 9295 | 시간 94[s] | 손실 2.41
# | 에폭 1 |  반복 4601 / 9295 | 시간 94[s] | 손실 2.39
# | 에폭 1 |  반복 4621 / 9295 | 시간 94[s] | 손실 2.38
# | 에폭 1 |  반복 4641 / 9295 | 시간 95[s] | 손실 2.42
# | 에폭 1 |  반복 4661 / 9295 | 시간 95[s] | 손실 2.35
# | 에폭 1 |  반복 4681 / 9295 | 시간 96[s] | 손실 2.40
# | 에폭 1 |  반복 4701 / 9295 | 시간 96[s] | 손실 2.38
# | 에폭 1 |  반복 4721 / 9295 | 시간 97[s] | 손실 2.38
# | 에폭 1 |  반복 4741 / 9295 | 시간 97[s] | 손실 2.40
# | 에폭 1 |  반복 4761 / 9295 | 시간 97[s] | 손실 2.37
# | 에폭 1 |  반복 4781 / 9295 | 시간 98[s] | 손실 2.38
# | 에폭 1 |  반복 4801 / 9295 | 시간 98[s] | 손실 2.40
# | 에폭 1 |  반복 4821 / 9295 | 시간 99[s] | 손실 2.38
# | 에폭 1 |  반복 4841 / 9295 | 시간 99[s] | 손실 2.37
# | 에폭 1 |  반복 4861 / 9295 | 시간 99[s] | 손실 2.38
# | 에폭 1 |  반복 4881 / 9295 | 시간 100[s] | 손실 2.34
# | 에폭 1 |  반복 4901 / 9295 | 시간 100[s] | 손실 2.38
# | 에폭 1 |  반복 4921 / 9295 | 시간 101[s] | 손실 2.36
# | 에폭 1 |  반복 4941 / 9295 | 시간 101[s] | 손실 2.39
# | 에폭 1 |  반복 4961 / 9295 | 시간 101[s] | 손실 2.36
# | 에폭 1 |  반복 4981 / 9295 | 시간 102[s] | 손실 2.34
# | 에폭 1 |  반복 5001 / 9295 | 시간 102[s] | 손실 2.37
# | 에폭 1 |  반복 5021 / 9295 | 시간 103[s] | 손실 2.40
# | 에폭 1 |  반복 5041 / 9295 | 시간 103[s] | 손실 2.37
# | 에폭 1 |  반복 5061 / 9295 | 시간 104[s] | 손실 2.38
# | 에폭 1 |  반복 5081 / 9295 | 시간 104[s] | 손실 2.38
# | 에폭 1 |  반복 5101 / 9295 | 시간 104[s] | 손실 2.34
# | 에폭 1 |  반복 5121 / 9295 | 시간 105[s] | 손실 2.39
# | 에폭 1 |  반복 5141 / 9295 | 시간 105[s] | 손실 2.36
# | 에폭 1 |  반복 5161 / 9295 | 시간 106[s] | 손실 2.35
# | 에폭 1 |  반복 5181 / 9295 | 시간 106[s] | 손실 2.38
# | 에폭 1 |  반복 5201 / 9295 | 시간 106[s] | 손실 2.38
# | 에폭 1 |  반복 5221 / 9295 | 시간 107[s] | 손실 2.38
# | 에폭 1 |  반복 5241 / 9295 | 시간 107[s] | 손실 2.36
# | 에폭 1 |  반복 5261 / 9295 | 시간 108[s] | 손실 2.36
# | 에폭 1 |  반복 5281 / 9295 | 시간 108[s] | 손실 2.33
# | 에폭 1 |  반복 5301 / 9295 | 시간 109[s] | 손실 2.34
# | 에폭 1 |  반복 5321 / 9295 | 시간 109[s] | 손실 2.37
# | 에폭 1 |  반복 5341 / 9295 | 시간 109[s] | 손실 2.41
# | 에폭 1 |  반복 5361 / 9295 | 시간 110[s] | 손실 2.36
# | 에폭 1 |  반복 5381 / 9295 | 시간 110[s] | 손실 2.34
# | 에폭 1 |  반복 5401 / 9295 | 시간 111[s] | 손실 2.34
# | 에폭 1 |  반복 5421 / 9295 | 시간 111[s] | 손실 2.32
# | 에폭 1 |  반복 5441 / 9295 | 시간 111[s] | 손실 2.36
# | 에폭 1 |  반복 5461 / 9295 | 시간 112[s] | 손실 2.36
# | 에폭 1 |  반복 5481 / 9295 | 시간 112[s] | 손실 2.35
# | 에폭 1 |  반복 5501 / 9295 | 시간 113[s] | 손실 2.32
# | 에폭 1 |  반복 5521 / 9295 | 시간 113[s] | 손실 2.37
# | 에폭 1 |  반복 5541 / 9295 | 시간 113[s] | 손실 2.36
# | 에폭 1 |  반복 5561 / 9295 | 시간 114[s] | 손실 2.34
# | 에폭 1 |  반복 5581 / 9295 | 시간 114[s] | 손실 2.32
# | 에폭 1 |  반복 5601 / 9295 | 시간 115[s] | 손실 2.36
# | 에폭 1 |  반복 5621 / 9295 | 시간 115[s] | 손실 2.37
# | 에폭 1 |  반복 5641 / 9295 | 시간 115[s] | 손실 2.34
# | 에폭 1 |  반복 5661 / 9295 | 시간 116[s] | 손실 2.36
# | 에폭 1 |  반복 5681 / 9295 | 시간 116[s] | 손실 2.36
# | 에폭 1 |  반복 5701 / 9295 | 시간 117[s] | 손실 2.38
# | 에폭 1 |  반복 5721 / 9295 | 시간 117[s] | 손실 2.33
# | 에폭 1 |  반복 5741 / 9295 | 시간 118[s] | 손실 2.36
# | 에폭 1 |  반복 5761 / 9295 | 시간 118[s] | 손실 2.31
# | 에폭 1 |  반복 5781 / 9295 | 시간 118[s] | 손실 2.34
# | 에폭 1 |  반복 5801 / 9295 | 시간 119[s] | 손실 2.33
# | 에폭 1 |  반복 5821 / 9295 | 시간 119[s] | 손실 2.36
# | 에폭 1 |  반복 5841 / 9295 | 시간 120[s] | 손실 2.35
# | 에폭 1 |  반복 5861 / 9295 | 시간 120[s] | 손실 2.30
# | 에폭 1 |  반복 5881 / 9295 | 시간 120[s] | 손실 2.34
# | 에폭 1 |  반복 5901 / 9295 | 시간 121[s] | 손실 2.37
# | 에폭 1 |  반복 5921 / 9295 | 시간 121[s] | 손실 2.34
# | 에폭 1 |  반복 5941 / 9295 | 시간 122[s] | 손실 2.37
# | 에폭 1 |  반복 5961 / 9295 | 시간 122[s] | 손실 2.35
# | 에폭 1 |  반복 5981 / 9295 | 시간 122[s] | 손실 2.32
# | 에폭 1 |  반복 6001 / 9295 | 시간 123[s] | 손실 2.33
# | 에폭 1 |  반복 6021 / 9295 | 시간 123[s] | 손실 2.35
# | 에폭 1 |  반복 6041 / 9295 | 시간 124[s] | 손실 2.35
# | 에폭 1 |  반복 6061 / 9295 | 시간 124[s] | 손실 2.35
# | 에폭 1 |  반복 6081 / 9295 | 시간 125[s] | 손실 2.33
# | 에폭 1 |  반복 6101 / 9295 | 시간 125[s] | 손실 2.35
# | 에폭 1 |  반복 6121 / 9295 | 시간 125[s] | 손실 2.34
# | 에폭 1 |  반복 6141 / 9295 | 시간 126[s] | 손실 2.31
# | 에폭 1 |  반복 6161 / 9295 | 시간 126[s] | 손실 2.31
# | 에폭 1 |  반복 6181 / 9295 | 시간 127[s] | 손실 2.32
# | 에폭 1 |  반복 6201 / 9295 | 시간 127[s] | 손실 2.31
# | 에폭 1 |  반복 6221 / 9295 | 시간 127[s] | 손실 2.32
# | 에폭 1 |  반복 6241 / 9295 | 시간 128[s] | 손실 2.32
# | 에폭 1 |  반복 6261 / 9295 | 시간 128[s] | 손실 2.35
# | 에폭 1 |  반복 6281 / 9295 | 시간 129[s] | 손실 2.34
# | 에폭 1 |  반복 6301 / 9295 | 시간 129[s] | 손실 2.33
# | 에폭 1 |  반복 6321 / 9295 | 시간 129[s] | 손실 2.29
# | 에폭 1 |  반복 6341 / 9295 | 시간 130[s] | 손실 2.34
# | 에폭 1 |  반복 6361 / 9295 | 시간 130[s] | 손실 2.34
# | 에폭 1 |  반복 6381 / 9295 | 시간 131[s] | 손실 2.33
# | 에폭 1 |  반복 6401 / 9295 | 시간 131[s] | 손실 2.33
# | 에폭 1 |  반복 6421 / 9295 | 시간 132[s] | 손실 2.32
# | 에폭 1 |  반복 6441 / 9295 | 시간 132[s] | 손실 2.34
# | 에폭 1 |  반복 6461 / 9295 | 시간 132[s] | 손실 2.34
# | 에폭 1 |  반복 6481 / 9295 | 시간 133[s] | 손실 2.33
# | 에폭 1 |  반복 6501 / 9295 | 시간 133[s] | 손실 2.31
# | 에폭 1 |  반복 6521 / 9295 | 시간 134[s] | 손실 2.29
# | 에폭 1 |  반복 6541 / 9295 | 시간 134[s] | 손실 2.31
# | 에폭 1 |  반복 6561 / 9295 | 시간 134[s] | 손실 2.34
# | 에폭 1 |  반복 6581 / 9295 | 시간 135[s] | 손실 2.30
# | 에폭 1 |  반복 6601 / 9295 | 시간 135[s] | 손실 2.32
# | 에폭 1 |  반복 6621 / 9295 | 시간 136[s] | 손실 2.33
# | 에폭 1 |  반복 6641 / 9295 | 시간 136[s] | 손실 2.31
# | 에폭 1 |  반복 6661 / 9295 | 시간 137[s] | 손실 2.34
# | 에폭 1 |  반복 6681 / 9295 | 시간 137[s] | 손실 2.28
# | 에폭 1 |  반복 6701 / 9295 | 시간 137[s] | 손실 2.29
# | 에폭 1 |  반복 6721 / 9295 | 시간 138[s] | 손실 2.29
# | 에폭 1 |  반복 6741 / 9295 | 시간 138[s] | 손실 2.33
# | 에폭 1 |  반복 6761 / 9295 | 시간 139[s] | 손실 2.33
# | 에폭 1 |  반복 6781 / 9295 | 시간 139[s] | 손실 2.32
# | 에폭 1 |  반복 6801 / 9295 | 시간 139[s] | 손실 2.32
# | 에폭 1 |  반복 6821 / 9295 | 시간 140[s] | 손실 2.31
# | 에폭 1 |  반복 6841 / 9295 | 시간 140[s] | 손실 2.29
# | 에폭 1 |  반복 6861 / 9295 | 시간 141[s] | 손실 2.32
# | 에폭 1 |  반복 6881 / 9295 | 시간 141[s] | 손실 2.30
# | 에폭 1 |  반복 6901 / 9295 | 시간 142[s] | 손실 2.32
# | 에폭 1 |  반복 6921 / 9295 | 시간 142[s] | 손실 2.30
# | 에폭 1 |  반복 6941 / 9295 | 시간 142[s] | 손실 2.32
# | 에폭 1 |  반복 6961 / 9295 | 시간 143[s] | 손실 2.33
# | 에폭 1 |  반복 6981 / 9295 | 시간 143[s] | 손실 2.30
# | 에폭 1 |  반복 7001 / 9295 | 시간 144[s] | 손실 2.29
# | 에폭 1 |  반복 7021 / 9295 | 시간 144[s] | 손실 2.29
# | 에폭 1 |  반복 7041 / 9295 | 시간 144[s] | 손실 2.33
# | 에폭 1 |  반복 7061 / 9295 | 시간 145[s] | 손실 2.28
# | 에폭 1 |  반복 7081 / 9295 | 시간 145[s] | 손실 2.31
# | 에폭 1 |  반복 7101 / 9295 | 시간 146[s] | 손실 2.28
# | 에폭 1 |  반복 7121 / 9295 | 시간 146[s] | 손실 2.31
# | 에폭 1 |  반복 7141 / 9295 | 시간 147[s] | 손실 2.29
# | 에폭 1 |  반복 7161 / 9295 | 시간 147[s] | 손실 2.31
# | 에폭 1 |  반복 7181 / 9295 | 시간 147[s] | 손실 2.26
# | 에폭 1 |  반복 7201 / 9295 | 시간 148[s] | 손실 2.30
# | 에폭 1 |  반복 7221 / 9295 | 시간 148[s] | 손실 2.30
# | 에폭 1 |  반복 7241 / 9295 | 시간 149[s] | 손실 2.31
# | 에폭 1 |  반복 7261 / 9295 | 시간 149[s] | 손실 2.29
# | 에폭 1 |  반복 7281 / 9295 | 시간 149[s] | 손실 2.27
# | 에폭 1 |  반복 7301 / 9295 | 시간 150[s] | 손실 2.31
# | 에폭 1 |  반복 7321 / 9295 | 시간 150[s] | 손실 2.32
# | 에폭 1 |  반복 7341 / 9295 | 시간 151[s] | 손실 2.29
# | 에폭 1 |  반복 7361 / 9295 | 시간 151[s] | 손실 2.27
# | 에폭 1 |  반복 7381 / 9295 | 시간 151[s] | 손실 2.26
# | 에폭 1 |  반복 7401 / 9295 | 시간 152[s] | 손실 2.30
# | 에폭 1 |  반복 7421 / 9295 | 시간 152[s] | 손실 2.31
# | 에폭 1 |  반복 7441 / 9295 | 시간 153[s] | 손실 2.29
# | 에폭 1 |  반복 7461 / 9295 | 시간 153[s] | 손실 2.30
# | 에폭 1 |  반복 7481 / 9295 | 시간 154[s] | 손실 2.29
# | 에폭 1 |  반복 7501 / 9295 | 시간 154[s] | 손실 2.27
# | 에폭 1 |  반복 7521 / 9295 | 시간 154[s] | 손실 2.29
# | 에폭 1 |  반복 7541 / 9295 | 시간 155[s] | 손실 2.29
# | 에폭 1 |  반복 7561 / 9295 | 시간 155[s] | 손실 2.28
# | 에폭 1 |  반복 7581 / 9295 | 시간 156[s] | 손실 2.28
# | 에폭 1 |  반복 7601 / 9295 | 시간 156[s] | 손실 2.32
# | 에폭 1 |  반복 7621 / 9295 | 시간 156[s] | 손실 2.28
# | 에폭 1 |  반복 7641 / 9295 | 시간 157[s] | 손실 2.30
# | 에폭 1 |  반복 7661 / 9295 | 시간 157[s] | 손실 2.29
# | 에폭 1 |  반복 7681 / 9295 | 시간 158[s] | 손실 2.27
# | 에폭 1 |  반복 7701 / 9295 | 시간 158[s] | 손실 2.27
# | 에폭 1 |  반복 7721 / 9295 | 시간 158[s] | 손실 2.29
# | 에폭 1 |  반복 7741 / 9295 | 시간 159[s] | 손실 2.28
# | 에폭 1 |  반복 7761 / 9295 | 시간 159[s] | 손실 2.29
# | 에폭 1 |  반복 7781 / 9295 | 시간 160[s] | 손실 2.27
# | 에폭 1 |  반복 7801 / 9295 | 시간 160[s] | 손실 2.24
# | 에폭 1 |  반복 7821 / 9295 | 시간 160[s] | 손실 2.29
# | 에폭 1 |  반복 7841 / 9295 | 시간 161[s] | 손실 2.29
# | 에폭 1 |  반복 7861 / 9295 | 시간 161[s] | 손실 2.27
# | 에폭 1 |  반복 7881 / 9295 | 시간 162[s] | 손실 2.24
# | 에폭 1 |  반복 7901 / 9295 | 시간 162[s] | 손실 2.31
# | 에폭 1 |  반복 7921 / 9295 | 시간 163[s] | 손실 2.29
# | 에폭 1 |  반복 7941 / 9295 | 시간 163[s] | 손실 2.28
# | 에폭 1 |  반복 7961 / 9295 | 시간 163[s] | 손실 2.29
# | 에폭 1 |  반복 7981 / 9295 | 시간 164[s] | 손실 2.28
# | 에폭 1 |  반복 8001 / 9295 | 시간 164[s] | 손실 2.29
# | 에폭 1 |  반복 8021 / 9295 | 시간 165[s] | 손실 2.30
# | 에폭 1 |  반복 8041 / 9295 | 시간 165[s] | 손실 2.26
# | 에폭 1 |  반복 8061 / 9295 | 시간 165[s] | 손실 2.28
# | 에폭 1 |  반복 8081 / 9295 | 시간 166[s] | 손실 2.29
# | 에폭 1 |  반복 8101 / 9295 | 시간 166[s] | 손실 2.25
# | 에폭 1 |  반복 8121 / 9295 | 시간 167[s] | 손실 2.29
# | 에폭 1 |  반복 8141 / 9295 | 시간 167[s] | 손실 2.26
# | 에폭 1 |  반복 8161 / 9295 | 시간 167[s] | 손실 2.25
# | 에폭 1 |  반복 8181 / 9295 | 시간 168[s] | 손실 2.28
# | 에폭 1 |  반복 8201 / 9295 | 시간 168[s] | 손실 2.23
# | 에폭 1 |  반복 8221 / 9295 | 시간 169[s] | 손실 2.28
# | 에폭 1 |  반복 8241 / 9295 | 시간 169[s] | 손실 2.24
# | 에폭 1 |  반복 8261 / 9295 | 시간 170[s] | 손실 2.25
# | 에폭 1 |  반복 8281 / 9295 | 시간 170[s] | 손실 2.28
# | 에폭 1 |  반복 8301 / 9295 | 시간 170[s] | 손실 2.23
# | 에폭 1 |  반복 8321 / 9295 | 시간 171[s] | 손실 2.29
# | 에폭 1 |  반복 8341 / 9295 | 시간 171[s] | 손실 2.27
# | 에폭 1 |  반복 8361 / 9295 | 시간 172[s] | 손실 2.28
# | 에폭 1 |  반복 8381 / 9295 | 시간 172[s] | 손실 2.28
# | 에폭 1 |  반복 8401 / 9295 | 시간 173[s] | 손실 2.25
# | 에폭 1 |  반복 8421 / 9295 | 시간 173[s] | 손실 2.26
# | 에폭 1 |  반복 8441 / 9295 | 시간 173[s] | 손실 2.26
# | 에폭 1 |  반복 8461 / 9295 | 시간 174[s] | 손실 2.24
# | 에폭 1 |  반복 8481 / 9295 | 시간 174[s] | 손실 2.25
# | 에폭 1 |  반복 8501 / 9295 | 시간 175[s] | 손실 2.27
# | 에폭 1 |  반복 8521 / 9295 | 시간 175[s] | 손실 2.25
# | 에폭 1 |  반복 8541 / 9295 | 시간 176[s] | 손실 2.25
# | 에폭 1 |  반복 8561 / 9295 | 시간 176[s] | 손실 2.27
# | 에폭 1 |  반복 8581 / 9295 | 시간 176[s] | 손실 2.28
# | 에폭 1 |  반복 8601 / 9295 | 시간 177[s] | 손실 2.23
# | 에폭 1 |  반복 8621 / 9295 | 시간 177[s] | 손실 2.27
# | 에폭 1 |  반복 8641 / 9295 | 시간 178[s] | 손실 2.22
# | 에폭 1 |  반복 8661 / 9295 | 시간 178[s] | 손실 2.25
# | 에폭 1 |  반복 8681 / 9295 | 시간 178[s] | 손실 2.24
# | 에폭 1 |  반복 8701 / 9295 | 시간 179[s] | 손실 2.27
# | 에폭 1 |  반복 8721 / 9295 | 시간 179[s] | 손실 2.23
# | 에폭 1 |  반복 8741 / 9295 | 시간 180[s] | 손실 2.23
# | 에폭 1 |  반복 8761 / 9295 | 시간 180[s] | 손실 2.22
# | 에폭 1 |  반복 8781 / 9295 | 시간 181[s] | 손실 2.24
# | 에폭 1 |  반복 8801 / 9295 | 시간 181[s] | 손실 2.25
# | 에폭 1 |  반복 8821 / 9295 | 시간 181[s] | 손실 2.25
# | 에폭 1 |  반복 8841 / 9295 | 시간 182[s] | 손실 2.26
# | 에폭 1 |  반복 8861 / 9295 | 시간 182[s] | 손실 2.25
# | 에폭 1 |  반복 8881 / 9295 | 시간 183[s] | 손실 2.25
# | 에폭 1 |  반복 8901 / 9295 | 시간 183[s] | 손실 2.24
# | 에폭 1 |  반복 8921 / 9295 | 시간 184[s] | 손실 2.29
# | 에폭 1 |  반복 8941 / 9295 | 시간 184[s] | 손실 2.25
# | 에폭 1 |  반복 8961 / 9295 | 시간 184[s] | 손실 2.22
# | 에폭 1 |  반복 8981 / 9295 | 시간 185[s] | 손실 2.25
# | 에폭 1 |  반복 9001 / 9295 | 시간 185[s] | 손실 2.25
# | 에폭 1 |  반복 9021 / 9295 | 시간 186[s] | 손실 2.22
# | 에폭 1 |  반복 9041 / 9295 | 시간 186[s] | 손실 2.26
# | 에폭 1 |  반복 9061 / 9295 | 시간 187[s] | 손실 2.24
# | 에폭 1 |  반복 9081 / 9295 | 시간 187[s] | 손실 2.22
# | 에폭 1 |  반복 9101 / 9295 | 시간 188[s] | 손실 2.20
# | 에폭 1 |  반복 9121 / 9295 | 시간 188[s] | 손실 2.27
# | 에폭 1 |  반복 9141 / 9295 | 시간 189[s] | 손실 2.24
# | 에폭 1 |  반복 9161 / 9295 | 시간 189[s] | 손실 2.27
# | 에폭 1 |  반복 9181 / 9295 | 시간 189[s] | 손실 2.22
# | 에폭 1 |  반복 9201 / 9295 | 시간 190[s] | 손실 2.24
# | 에폭 1 |  반복 9221 / 9295 | 시간 190[s] | 손실 2.22
# | 에폭 1 |  반복 9241 / 9295 | 시간 191[s] | 손실 2.25
# | 에폭 1 |  반복 9261 / 9295 | 시간 191[s] | 손실 2.26
# | 에폭 1 |  반복 9281 / 9295 | 시간 192[s] | 손실 2.23
# C:\Users\rltjq\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rltjq\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48373 (\N{HANGUL SYLLABLE BOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rltjq\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rltjq\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17480/621329027.py in <cell line: 40>()
#      38     word_vecs = to_cpu(word_vecs)
#      39 params = {}
# ---> 40 params['word_vecs'] = word_vecs.astype(np.float16)
#      41 params['word_to_id'] = word_to_id
#      42 params['id_to_word'] = id_to_word
#
# NameError: name 'np' is not defined

# %%
import sys
sys.path.append('..')
from common.util import most_similar
import pickle

pkl_file = 'cbow_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']
    
querys = ['you', 'year', 'car','toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875
#
# [query] toyota
#  ford: 0.55078125
#  instrumentation: 0.509765625
#  mazda: 0.49365234375
#  bethlehem: 0.47509765625
#  nissan: 0.474853515625
