# %%
import sys
sys.path.append('..')
import numpy as np
from common.functions import softmax
from ch06.rnnlm import Rnnlm
from ch06.better_rnnlm import BetterRnnlm

class RnnlmGen(Rnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]
        
        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x)
            p = softmax(score.flatten())
            
            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))
        
        return word_ids

# %%
import sys
sys.path.append('..')
from rnnlm_gen import RnnlmGen
from dataset import ptb

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

model = RnnlmGen()
model.load_params('../ch06/Rnnlm.pkl')

# 시작 문자와 건너뜀 문자 설정
start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>','$']
skip_ids = [word_to_id[w] for w in skip_words]

# 문장 생성
word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you could still encourage the project before it will be purchased for policies.
#  overall less half of the time was announced oct. walker house group has n't yet been formed by sen. pont & co. group inc. on the reagan administration.
#  when nicaragua controls includes its state employees and sent control corp. of waiver strength.
#  the supreme court said chamber believed that officials is powerful pencils containing headquarters seeking to tackle plaintiffs fled after law and political administration volume but no threat to reform.
#  that they participated in the second steps.
#  carnival officials said the

# %%
import sys
sys.path.append('..')
from dataset import sequence

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt', seed=1984)
char_to_id, id_to_char = sequence.get_vocab()

# %%
class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        v, d, h = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        embed_w = (rn(v, d) / 100).astype('f')
        lstm_wx = (rn(d, 4 * h) / np.sqrt(d)).astype('f')
        lstm_wh = (rn(h, 4 * h) / np.sqrt(h)).astype('f')
        lstm_b = np.zeros(4 * h).astype('f')
        
        self.embed = TimeEmbedding(embed_w)
        self.lstm = TimeLSTM(lstm_wx, lstm_wh, lstm_b, stateful=False)
        
        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None
        
    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh
        
        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %%
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        v, d, h = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        embed_w = (rn(v, d) / 100).astype('f')
        lstm_wx = (rn(d, 4 * h) / np.sqrt(d)).astype('f')
        lstm_wh = (rn(h, 4 * h) / np.sqrt(h)).astype('f')
        lstm_b = np.zeros(4 * h).astype('f')
        affine_w = (rn(h, v) / np.sqrt(h)).astype('f')
        affine_b = np.zeros(v).astype('f')
        
        self.embed = TimeEmbedding(embed_w)
        self.lstm = TimeLSTM(lstm_wx, lstm_wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_w, affine_b)
        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
            
    def forward(self, xs, h):
        self.lstm.set_state(h)
        
        out = self.lstm.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score
    
    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh
    
    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id =start_id
        self.lstm.set_state(h)
        
        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)
            
            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))
            
        return sampled

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 모델 / 옵티마이저 / 트레이너 생성
model = Seq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.53
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.92
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.83
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 3[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 281 / 351 | 시간 6[s] | 손실 1.75
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 7[s] | 손실 1.75
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.74
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 1000
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 1000
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1000
# ---
# Q 26+838
# T 864
# X 1000
# ---
# Q 143+93
# T 236
# X 100
# ---
# 검증 정확도 0.180%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.73
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.74
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.73
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.73
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.72
# | 에폭 2 |  반복 141 / 351 | 시간 3[s] | 손실 1.71
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.71
# | 에폭 2 |  반복 181 / 351 | 시간 4[s] | 손실 1.71
# | 에폭 2 |  반복 201 / 351 | 시간 4[s] | 손실 1.70
# | 에폭 2 |  반복 221 / 351 | 시간 4[s] | 손실 1.71
# | 에폭 2 |  반복 241 / 351 | 시간 5[s] | 손실 1.70
# | 에폭 2 |  반복 261 / 351 | 시간 5[s] | 손실 1.69
# | 에폭 2 |  반복 281 / 351 | 시간 6[s] | 손실 1.69
# | 에폭 2 |  반복 301 / 351 | 시간 6[s] | 손실 1.69
# | 에폭 2 |  반복 321 / 351 | 시간 7[s] | 손실 1.68
# | 에폭 2 |  반복 341 / 351 | 시간 7[s] | 손실 1.67
# Q 77+85
# T 162
# X 994
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 700
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 400
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1544
# ---
# Q 26+838
# T 864
# X 400
# ---
# Q 143+93
# T 236
# X 400
# ---
# 검증 정확도 0.220%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.65
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.63
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.62
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.62
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.60
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.59
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.57
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.57
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 1.56
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.54
# | 에폭 3 |  반복 241 / 351 | 시간 5[s] | 손실 1.52
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 1.52
# | 에폭 3 |  반복 281 / 351 | 시간 6[s] | 손실 1.52
# | 에폭 3 |  반복 301 / 351 | 시간 7[s] | 손실 1.50
# | 에폭 3 |  반복 321 / 351 | 시간 7[s] | 손실 1.49
# | 에폭 3 |  반복 341 / 351 | 시간 8[s] | 손실 1.48
# Q 77+85
# T 162
# X 108
# ---
# Q 975+164
# T 1139
# X 1001
# ---
# Q 582+84
# T 666
# X 648
# ---
# Q 8+155
# T 163
# X 138
# ---
# Q 367+55
# T 422
# X 448
# ---
# Q 600+257
# T 857
# X 848
# ---
# Q 761+292
# T 1053
# X 1011
# ---
# Q 830+597
# T 1427
# X 1373
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 348
# ---
# 검증 정확도 0.560%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.47
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.46
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.44
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.43
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 1.42
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.41
# | 에폭 4 |  반복 121 / 351 | 시간 2[s] | 손실 1.40
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 1.40
# | 에폭 4 |  반복 161 / 351 | 시간 3[s] | 손실 1.38
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 1.38
# | 에폭 4 |  반복 201 / 351 | 시간 4[s] | 손실 1.37
# | 에폭 4 |  반복 221 / 351 | 시간 5[s] | 손실 1.35
# | 에폭 4 |  반복 241 / 351 | 시간 5[s] | 손실 1.33
# | 에폭 4 |  반복 261 / 351 | 시간 6[s] | 손실 1.33
# | 에폭 4 |  반복 281 / 351 | 시간 6[s] | 손실 1.33
# | 에폭 4 |  반복 301 / 351 | 시간 7[s] | 손실 1.32
# | 에폭 4 |  반복 321 / 351 | 시간 7[s] | 손실 1.31
# | 에폭 4 |  반복 341 / 351 | 시간 8[s] | 손실 1.30
# Q 77+85
# T 162
# X 146
# ---
# Q 975+164
# T 1139
# X 1189
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 432
# ---
# Q 600+257
# T 857
# X 866
# ---
# Q 761+292
# T 1053
# X 1002
# ---
# Q 830+597
# T 1427
# X 1406
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 202
# ---
# 검증 정확도 1.060%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.29
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.28
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 1.27
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 1.26
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 1.26
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 1.27
# | 에폭 5 |  반복 161 / 351 | 시간 4[s] | 손실 1.26
# | 에폭 5 |  반복 181 / 351 | 시간 4[s] | 손실 1.25
# | 에폭 5 |  반복 201 / 351 | 시간 5[s] | 손실 1.23
# | 에폭 5 |  반복 221 / 351 | 시간 5[s] | 손실 1.22
# | 에폭 5 |  반복 241 / 351 | 시간 6[s] | 손실 1.21
# | 에폭 5 |  반복 261 / 351 | 시간 6[s] | 손실 1.21
# | 에폭 5 |  반복 281 / 351 | 시간 7[s] | 손실 1.21
# | 에폭 5 |  반복 301 / 351 | 시간 7[s] | 손실 1.20
# | 에폭 5 |  반복 321 / 351 | 시간 8[s] | 손실 1.19
# | 에폭 5 |  반복 341 / 351 | 시간 8[s] | 손실 1.18
# Q 77+85
# T 162
# X 145
# ---
# Q 975+164
# T 1139
# X 1168
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 192
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 895
# ---
# Q 761+292
# T 1053
# X 1015
# ---
# Q 830+597
# T 1427
# X 1493
# ---
# Q 26+838
# T 864
# X 891
# ---
# Q 143+93
# T 236
# X 221
# ---
# 검증 정확도 2.260%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 1.18
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 1.17
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 1.16
# | 에폭 6 |  반복 141 / 351 | 시간 3[s] | 손실 1.14
# | 에폭 6 |  반복 161 / 351 | 시간 4[s] | 손실 1.14
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 1.13
# | 에폭 6 |  반복 201 / 351 | 시간 5[s] | 손실 1.15
# | 에폭 6 |  반복 221 / 351 | 시간 5[s] | 손실 1.13
# | 에폭 6 |  반복 241 / 351 | 시간 6[s] | 손실 1.13
# | 에폭 6 |  반복 261 / 351 | 시간 6[s] | 손실 1.11
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 1.12
# | 에폭 6 |  반복 301 / 351 | 시간 7[s] | 손실 1.13
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 1.11
# | 에폭 6 |  반복 341 / 351 | 시간 8[s] | 손실 1.10
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1191
# ---
# Q 582+84
# T 666
# X 660
# ---
# Q 8+155
# T 163
# X 196
# ---
# Q 367+55
# T 422
# X 411
# ---
# Q 600+257
# T 857
# X 846
# ---
# Q 761+292
# T 1053
# X 1011
# ---
# Q 830+597
# T 1427
# X 1410
# ---
# Q 26+838
# T 864
# X 840
# ---
# Q 143+93
# T 236
# X 207
# ---
# 검증 정확도 2.320%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.11
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 1.11
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 1.15
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 1.13
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 1.13
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 1.10
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 1.08
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 1.08
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 1.07
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 1.08
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 1.08
# | 에폭 7 |  반복 221 / 351 | 시간 5[s] | 손실 1.06
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 1.05
# | 에폭 7 |  반복 261 / 351 | 시간 6[s] | 손실 1.06
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 1.07
# | 에폭 7 |  반복 301 / 351 | 시간 7[s] | 손실 1.06
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 1.07
# | 에폭 7 |  반복 341 / 351 | 시간 8[s] | 손실 1.04
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1166
# ---
# Q 582+84
# T 666
# X 695
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# X 893
# ---
# Q 761+292
# T 1053
# X 1056
# ---
# Q 830+597
# T 1427
# X 1460
# ---
# Q 26+838
# T 864
# X 893
# ---
# Q 143+93
# T 236
# X 227
# ---
# 검증 정확도 2.640%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.10
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 1.06
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 1.06
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 1.04
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 1.04
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 1.03
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 1.05
# | 에폭 8 |  반복 161 / 351 | 시간 4[s] | 손실 1.05
# | 에폭 8 |  반복 181 / 351 | 시간 4[s] | 손실 1.02
# | 에폭 8 |  반복 201 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 8 |  반복 221 / 351 | 시간 5[s] | 손실 1.01
# | 에폭 8 |  반복 241 / 351 | 시간 6[s] | 손실 1.01
# | 에폭 8 |  반복 261 / 351 | 시간 6[s] | 손실 1.06
# | 에폭 8 |  반복 281 / 351 | 시간 7[s] | 손실 1.01
# | 에폭 8 |  반복 301 / 351 | 시간 7[s] | 손실 1.01
# | 에폭 8 |  반복 321 / 351 | 시간 8[s] | 손실 1.00
# | 에폭 8 |  반복 341 / 351 | 시간 8[s] | 손실 1.01
# Q 77+85
# T 162
# X 156
# ---
# Q 975+164
# T 1139
# X 1108
# ---
# Q 582+84
# T 666
# X 658
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# X 411
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1009
# ---
# Q 830+597
# T 1427
# X 1410
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 207
# ---
# 검증 정확도 3.580%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.99
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 1.02
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 1.03
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 1.01
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 0.98
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.99
# | 에폭 9 |  반복 221 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 9 |  반복 241 / 351 | 시간 6[s] | 손실 0.99
# | 에폭 9 |  반복 261 / 351 | 시간 6[s] | 손실 0.99
# | 에폭 9 |  반복 281 / 351 | 시간 7[s] | 손실 0.98
# | 에폭 9 |  반복 301 / 351 | 시간 7[s] | 손실 0.97
# | 에폭 9 |  반복 321 / 351 | 시간 8[s] | 손실 0.97
# | 에폭 9 |  반복 341 / 351 | 시간 8[s] | 손실 0.97
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1123
# ---
# Q 582+84
# T 666
# X 661
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 227
# ---
# 검증 정확도 5.140%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.97
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.96
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.97
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 10 |  반복 221 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 10 |  반복 261 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 10 |  반복 281 / 351 | 시간 7[s] | 손실 0.95
# | 에폭 10 |  반복 301 / 351 | 시간 7[s] | 손실 0.96
# | 에폭 10 |  반복 321 / 351 | 시간 8[s] | 손실 0.95
# | 에폭 10 |  반복 341 / 351 | 시간 8[s] | 손실 0.94
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1126
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 170
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 240
# ---
# 검증 정확도 5.680%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.95
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.95
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.94
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 0.98
# | 에폭 11 |  반복 121 / 351 | 시간 3[s] | 손실 0.96
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 11 |  반복 161 / 351 | 시간 4[s] | 손실 0.95
# | 에폭 11 |  반복 181 / 351 | 시간 4[s] | 손실 0.94
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 11 |  반복 221 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 11 |  반복 261 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 11 |  반복 281 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 11 |  반복 301 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 11 |  반복 321 / 351 | 시간 8[s] | 손실 0.95
# | 에폭 11 |  반복 341 / 351 | 시간 8[s] | 손실 0.95
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1059
# ---
# Q 830+597
# T 1427
# X 1456
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 6.060%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.93
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.93
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.96
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 12 |  반복 181 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 12 |  반복 201 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 12 |  반복 221 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 12 |  반복 241 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 12 |  반복 261 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 12 |  반복 281 / 351 | 시간 7[s] | 손실 0.95
# | 에폭 12 |  반복 301 / 351 | 시간 7[s] | 손실 0.98
# | 에폭 12 |  반복 321 / 351 | 시간 8[s] | 손실 0.93
# | 에폭 12 |  반복 341 / 351 | 시간 8[s] | 손실 0.91
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 681
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 427
# ---
# Q 600+257
# T 857
# X 870
# ---
# Q 761+292
# T 1053
# X 1059
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 871
# ---
# Q 143+93
# T 236
# X 229
# ---
# 검증 정확도 5.980%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.91
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 0.90
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.94
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 13 |  반복 161 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 13 |  반복 181 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 13 |  반복 201 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 13 |  반복 221 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 13 |  반복 241 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 13 |  반복 261 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 13 |  반복 281 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 13 |  반복 301 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 13 |  반복 321 / 351 | 시간 8[s] | 손실 0.96
# | 에폭 13 |  반복 341 / 351 | 시간 8[s] | 손실 0.90
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1118
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 167
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1414
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 7.940%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.89
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.88
# | 에폭 14 |  반복 121 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 0.94
# | 에폭 14 |  반복 161 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 14 |  반복 181 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 14 |  반복 201 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 14 |  반복 221 / 351 | 시간 5[s] | 손실 0.88
# | 에폭 14 |  반복 241 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 14 |  반복 261 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 14 |  반복 281 / 351 | 시간 7[s] | 손실 0.91
# | 에폭 14 |  반복 301 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 14 |  반복 321 / 351 | 시간 8[s] | 손실 0.91
# | 에폭 14 |  반복 341 / 351 | 시간 8[s] | 손실 0.90
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 428
# ---
# Q 600+257
# T 857
# X 870
# ---
# Q 761+292
# T 1053
# X 1072
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 7.560%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.86
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 15 |  반복 121 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 15 |  반복 141 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 15 |  반복 161 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 15 |  반복 181 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 15 |  반복 201 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 15 |  반복 221 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 15 |  반복 241 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 15 |  반복 261 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 15 |  반복 281 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 15 |  반복 301 / 351 | 시간 7[s] | 손실 0.87
# | 에폭 15 |  반복 321 / 351 | 시간 8[s] | 손실 0.87
# | 에폭 15 |  반복 341 / 351 | 시간 8[s] | 손실 0.89
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1126
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 172
# ---
# Q 367+55
# T 422
# X 413
# ---
# Q 600+257
# T 857
# X 846
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1421
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 227
# ---
# 검증 정확도 6.460%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 16 |  반복 141 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 16 |  반복 161 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 16 |  반복 181 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 16 |  반복 201 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 16 |  반복 221 / 351 | 시간 5[s] | 손실 0.87
# | 에폭 16 |  반복 241 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 16 |  반복 261 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 16 |  반복 281 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 16 |  반복 301 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 16 |  반복 321 / 351 | 시간 8[s] | 손실 0.85
# | 에폭 16 |  반복 341 / 351 | 시간 8[s] | 손실 0.86
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1129
# ---
# Q 582+84
# T 666
# X 677
# ---
# Q 8+155
# T 163
# X 159
# ---
# Q 367+55
# T 422
# X 427
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1072
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 872
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 4.440%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.88
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 17 |  반복 121 / 351 | 시간 3[s] | 손실 0.85
# | 에폭 17 |  반복 141 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 17 |  반복 161 / 351 | 시간 4[s] | 손실 0.86
# | 에폭 17 |  반복 181 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 17 |  반복 201 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 17 |  반복 221 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 17 |  반복 241 / 351 | 시간 6[s] | 손실 0.86
# | 에폭 17 |  반복 261 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 17 |  반복 281 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 17 |  반복 301 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 17 |  반복 321 / 351 | 시간 8[s] | 손실 0.83
# | 에폭 17 |  반복 341 / 351 | 시간 8[s] | 손실 0.83
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 675
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 424
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1414
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 10.380%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 18 |  반복 81 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 18 |  반복 121 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 18 |  반복 141 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 18 |  반복 161 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 18 |  반복 181 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 18 |  반복 221 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 18 |  반복 261 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 18 |  반복 281 / 351 | 시간 6[s] | 손실 0.86
# | 에폭 18 |  반복 301 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 18 |  반복 321 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 18 |  반복 341 / 351 | 시간 8[s] | 손실 0.85
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1128
# ---
# Q 582+84
# T 666
# X 657
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1414
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 5.720%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 19 |  반복 121 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 19 |  반복 141 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 19 |  반복 161 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 19 |  반복 181 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 19 |  반복 201 / 351 | 시간 5[s] | 손실 0.85
# | 에폭 19 |  반복 221 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 19 |  반복 241 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 19 |  반복 261 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 19 |  반복 281 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 19 |  반복 301 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 19 |  반복 321 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 19 |  반복 341 / 351 | 시간 8[s] | 손실 0.85
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1162
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 158
# ---
# Q 367+55
# T 422
# X 427
# ---
# Q 600+257
# T 857
# X 862
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1449
# ---
# Q 26+838
# T 864
# X 872
# ---
# Q 143+93
# T 236
# X 247
# ---
# 검증 정확도 6.460%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 20 |  반복 81 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 20 |  반복 121 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.83
# | 에폭 20 |  반복 161 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 20 |  반복 201 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 20 |  반복 221 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 20 |  반복 241 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 20 |  반복 261 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 20 |  반복 281 / 351 | 시간 6[s] | 손실 0.79
# | 에폭 20 |  반복 301 / 351 | 시간 7[s] | 손실 0.83
# | 에폭 20 |  반복 321 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 20 |  반복 341 / 351 | 시간 8[s] | 손실 0.80
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1131
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 872
# ---
# Q 143+93
# T 236
# X 245
# ---
# 검증 정확도 8.900%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 21 |  반복 41 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 21 |  반복 81 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 21 |  반복 121 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 0.89
# | 에폭 21 |  반복 161 / 351 | 시간 3[s] | 손실 0.81
# | 에폭 21 |  반복 181 / 351 | 시간 4[s] | 손실 0.84
# | 에폭 21 |  반복 201 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 21 |  반복 221 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 21 |  반복 241 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 21 |  반복 261 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 21 |  반복 281 / 351 | 시간 6[s] | 손실 0.79
# | 에폭 21 |  반복 301 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 21 |  반복 321 / 351 | 시간 7[s] | 손실 0.81
# | 에폭 21 |  반복 341 / 351 | 시간 8[s] | 손실 0.80
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 424
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1069
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 8.000%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 22 |  반복 41 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 22 |  반복 81 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 22 |  반복 121 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 22 |  반복 161 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 22 |  반복 181 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 22 |  반복 201 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 22 |  반복 221 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 22 |  반복 241 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 22 |  반복 261 / 351 | 시간 6[s] | 손실 0.79
# | 에폭 22 |  반복 281 / 351 | 시간 6[s] | 손실 0.79
# | 에폭 22 |  반복 301 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 22 |  반복 321 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 22 |  반복 341 / 351 | 시간 8[s] | 손실 0.80
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1130
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 167
# ---
# Q 367+55
# T 422
# X 427
# ---
# Q 600+257
# T 857
# X 850
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1420
# ---
# Q 26+838
# T 864
# X 875
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 10.080%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 23 |  반복 41 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 23 |  반복 81 / 351 | 시간 1[s] | 손실 0.81
# | 에폭 23 |  반복 101 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 23 |  반복 121 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 23 |  반복 141 / 351 | 시간 3[s] | 손실 0.78
# | 에폭 23 |  반복 161 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 23 |  반복 181 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 23 |  반복 201 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 23 |  반복 221 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 23 |  반복 241 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 23 |  반복 261 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 23 |  반복 281 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 23 |  반복 301 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 23 |  반복 321 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 23 |  반복 341 / 351 | 시간 8[s] | 손실 0.80
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 669
# ---
# Q 8+155
# T 163
# X 165
# ---
# Q 367+55
# T 422
# X 429
# ---
# Q 600+257
# T 857
# X 861
# ---
# Q 761+292
# T 1053
# X 1070
# ---
# Q 830+597
# T 1427
# X 1451
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 4.720%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 24 |  반복 41 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 24 |  반복 81 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.79
# | 에폭 24 |  반복 121 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 24 |  반복 141 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 24 |  반복 161 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 24 |  반복 181 / 351 | 시간 4[s] | 손실 0.80
# | 에폭 24 |  반복 201 / 351 | 시간 4[s] | 손실 0.80
# | 에폭 24 |  반복 221 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 24 |  반복 241 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 24 |  반복 261 / 351 | 시간 6[s] | 손실 0.78
# | 에폭 24 |  반복 281 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 24 |  반복 301 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 24 |  반복 321 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 24 |  반복 341 / 351 | 시간 8[s] | 손실 0.78
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# X 417
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 229
# ---
# 검증 정확도 10.840%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.74
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 25 |  반복 41 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.78
# | 에폭 25 |  반복 81 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 25 |  반복 121 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 25 |  반복 161 / 351 | 시간 3[s] | 손실 0.78
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 0.76
# | 에폭 25 |  반복 201 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 25 |  반복 221 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 25 |  반복 241 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 25 |  반복 261 / 351 | 시간 6[s] | 손실 0.77
# | 에폭 25 |  반복 281 / 351 | 시간 6[s] | 손실 0.77
# | 에폭 25 |  반복 301 / 351 | 시간 7[s] | 손실 0.77
# | 에폭 25 |  반복 321 / 351 | 시간 7[s] | 손실 0.77
# | 에폭 25 |  반복 341 / 351 | 시간 8[s] | 손실 0.78
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 12.520%

# %%
plt.plot(range(len(acc_list)), acc_list, 'o-')
plt.ylim([0,1])
plt.show()

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 모델 / 옵티마이저 / 트레이너 생성
model = Seq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

racc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
    acc = float(correct_num) / len(x_test)
    racc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.52
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.91
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.86
# | 에폭 1 |  반복 141 / 351 | 시간 2[s] | 손실 1.84
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.80
# | 에폭 1 |  반복 181 / 351 | 시간 3[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 241 / 351 | 시간 4[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 5[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.73
# Q   58+77
# T 162
# X 100
# ---
# Q 461+579
# T 1139
# X 1000
# ---
# Q  48+285
# T 666
# X 1001
# ---
# Q   551+8
# T 163
# X 100
# ---
# Q  55+763
# T 422
# X 1001
# ---
# Q 752+006
# T 857
# X 1000
# ---
# Q 292+167
# T 1053
# X 1000
# ---
# Q 795+038
# T 1427
# X 1000
# ---
# Q  838+62
# T 864
# X 1001
# ---
# Q  39+341
# T 236
# X 703
# ---
# 검증 정확도 0.120%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.73
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.72
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.70
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.69
# | 에폭 2 |  반복 141 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.67
# | 에폭 2 |  반복 181 / 351 | 시간 3[s] | 손실 1.66
# | 에폭 2 |  반복 201 / 351 | 시간 4[s] | 손실 1.66
# | 에폭 2 |  반복 221 / 351 | 시간 4[s] | 손실 1.65
# | 에폭 2 |  반복 241 / 351 | 시간 5[s] | 손실 1.63
# | 에폭 2 |  반복 261 / 351 | 시간 5[s] | 손실 1.62
# | 에폭 2 |  반복 281 / 351 | 시간 5[s] | 손실 1.61
# | 에폭 2 |  반복 301 / 351 | 시간 6[s] | 손실 1.60
# | 에폭 2 |  반복 321 / 351 | 시간 6[s] | 손실 1.58
# | 에폭 2 |  반복 341 / 351 | 시간 7[s] | 손실 1.56
# Q   58+77
# T 162
# X 100
# ---
# Q 461+579
# T 1139
# X 1000
# ---
# Q  48+285
# T 666
# X 690
# ---
# Q   551+8
# T 163
# X 1000
# ---
# Q  55+763
# T 422
# X 470
# ---
# Q 752+006
# T 857
# X 700
# ---
# Q 292+167
# T 1053
# X 1000
# ---
# Q 795+038
# T 1427
# X 1444
# ---
# Q  838+62
# T 864
# X 700
# ---
# Q  39+341
# T 236
# X 370
# ---
# 검증 정확도 0.400%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.52
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.53
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.51
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.49
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.47
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.45
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.44
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.42
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.40
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.38
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 1.37
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.35
# | 에폭 3 |  반복 241 / 351 | 시간 5[s] | 손실 1.33
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 1.32
# | 에폭 3 |  반복 281 / 351 | 시간 6[s] | 손실 1.30
# | 에폭 3 |  반복 301 / 351 | 시간 6[s] | 손실 1.29
# | 에폭 3 |  반복 321 / 351 | 시간 7[s] | 손실 1.28
# | 에폭 3 |  반복 341 / 351 | 시간 7[s] | 손실 1.27
# Q   58+77
# T 162
# X 158
# ---
# Q 461+579
# T 1139
# X 1148
# ---
# Q  48+285
# T 666
# X 662
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 382
# ---
# Q 752+006
# T 857
# X 818
# ---
# Q 292+167
# T 1053
# X 1008
# ---
# Q 795+038
# T 1427
# X 1434
# ---
# Q  838+62
# T 864
# X 838
# ---
# Q  39+341
# T 236
# X 202
# ---
# 검증 정확도 1.940%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.26
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.25
# | 에폭 4 |  반복 41 / 351 | 시간 0[s] | 손실 1.23
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.22
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 1.20
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.19
# | 에폭 4 |  반복 121 / 351 | 시간 3[s] | 손실 1.18
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 1.17
# | 에폭 4 |  반복 161 / 351 | 시간 4[s] | 손실 1.15
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 1.13
# | 에폭 4 |  반복 201 / 351 | 시간 5[s] | 손실 1.12
# | 에폭 4 |  반복 221 / 351 | 시간 5[s] | 손실 1.11
# | 에폭 4 |  반복 241 / 351 | 시간 6[s] | 손실 1.09
# | 에폭 4 |  반복 261 / 351 | 시간 6[s] | 손실 1.08
# | 에폭 4 |  반복 281 / 351 | 시간 7[s] | 손실 1.07
# | 에폭 4 |  반복 301 / 351 | 시간 7[s] | 손실 1.07
# | 에폭 4 |  반복 321 / 351 | 시간 8[s] | 손실 1.05
# | 에폭 4 |  반복 341 / 351 | 시간 8[s] | 손실 1.03
# Q   58+77
# T 162
# X 166
# ---
# Q 461+579
# T 1139
# X 1196
# ---
# Q  48+285
# T 666
# X 668
# ---
# Q   551+8
# T 163
# X 166
# ---
# Q  55+763
# T 422
# X 419
# ---
# Q 752+006
# T 857
# X 896
# ---
# Q 292+167
# T 1053
# X 1010
# ---
# Q 795+038
# T 1427
# X 1496
# ---
# Q  838+62
# T 864
# X 868
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 5.780%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 5 |  반복 81 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 5 |  반복 121 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 0.94
# | 에폭 5 |  반복 161 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 5 |  반복 181 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 5 |  반복 201 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 5 |  반복 221 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 5 |  반복 241 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 5 |  반복 261 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 5 |  반복 281 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 5 |  반복 301 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 5 |  반복 321 / 351 | 시간 7[s] | 손실 0.85
# | 에폭 5 |  반복 341 / 351 | 시간 8[s] | 손실 0.84
# Q   58+77
# T 162
# X 161
# ---
# Q 461+579
# T 1139
# X 1192
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 166
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# X 860
# ---
# Q 292+167
# T 1053
# X 1066
# ---
# Q 795+038
# T 1427
# X 1414
# ---
# Q  838+62
# T 864
# X 865
# ---
# Q  39+341
# T 236
# X 232
# ---
# 검증 정확도 12.460%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.81
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 6 |  반복 141 / 351 | 시간 3[s] | 손실 0.78
# | 에폭 6 |  반복 161 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 6 |  반복 201 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 6 |  반복 221 / 351 | 시간 5[s] | 손실 0.76
# | 에폭 6 |  반복 241 / 351 | 시간 6[s] | 손실 0.75
# | 에폭 6 |  반복 261 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 6 |  반복 301 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 6 |  반복 341 / 351 | 시간 8[s] | 손실 0.72
# Q   58+77
# T 162
# X 161
# ---
# Q 461+579
# T 1139
# X 1141
# ---
# Q  48+285
# T 666
# X 661
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 851
# ---
# Q 292+167
# T 1053
# X 1061
# ---
# Q 795+038
# T 1427
# X 1391
# ---
# Q  838+62
# T 864
# X 866
# ---
# Q  39+341
# T 236
# X 234
# ---
# 검증 정확도 14.260%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.70
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 0.70
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 7 |  반복 221 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 0.64
# | 에폭 7 |  반복 261 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 0.64
# | 에폭 7 |  반복 301 / 351 | 시간 7[s] | 손실 0.63
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 0.63
# | 에폭 7 |  반복 341 / 351 | 시간 8[s] | 손실 0.62
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1142
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 859
# ---
# Q 292+167
# T 1053
# X 1144
# ---
# Q 795+038
# T 1427
# X 1431
# ---
# Q  838+62
# T 864
# X 866
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 17.500%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.66
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.61
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.62
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.61
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 8 |  반복 161 / 351 | 시간 4[s] | 손실 0.59
# | 에폭 8 |  반복 181 / 351 | 시간 4[s] | 손실 0.58
# | 에폭 8 |  반복 201 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 8 |  반복 221 / 351 | 시간 5[s] | 손실 0.60
# | 에폭 8 |  반복 241 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 8 |  반복 261 / 351 | 시간 6[s] | 손실 0.58
# | 에폭 8 |  반복 281 / 351 | 시간 7[s] | 손실 0.59
# | 에폭 8 |  반복 301 / 351 | 시간 7[s] | 손실 0.58
# | 에폭 8 |  반복 321 / 351 | 시간 8[s] | 손실 0.57
# | 에폭 8 |  반복 341 / 351 | 시간 8[s] | 손실 0.57
# Q   58+77
# T 162
# X 163
# ---
# Q 461+579
# T 1139
# X 1134
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 759
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1431
# ---
# Q  838+62
# T 864
# X 866
# ---
# Q  39+341
# T 236
# X 238
# ---
# 검증 정확도 23.080%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.56
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.54
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 9 |  반복 121 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 0.54
# | 에폭 9 |  반복 161 / 351 | 시간 3[s] | 손실 0.55
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 9 |  반복 201 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 9 |  반복 221 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 9 |  반복 241 / 351 | 시간 5[s] | 손실 0.53
# | 에폭 9 |  반복 261 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 9 |  반복 281 / 351 | 시간 6[s] | 손실 0.54
# | 에폭 9 |  반복 301 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 9 |  반복 321 / 351 | 시간 7[s] | 손실 0.53
# | 에폭 9 |  반복 341 / 351 | 시간 8[s] | 손실 0.53
# Q   58+77
# T 162
# X 158
# ---
# Q 461+579
# T 1139
# X 1142
# ---
# Q  48+285
# T 666
# X 664
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 854
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# X 862
# ---
# Q  39+341
# T 236
# X 238
# ---
# 검증 정확도 26.520%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.52
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.52
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 0.50
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.51
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.50
# | 에폭 10 |  반복 221 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 10 |  반복 261 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 10 |  반복 281 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 10 |  반복 301 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 10 |  반복 321 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 10 |  반복 341 / 351 | 시간 9[s] | 손실 0.48
# Q   58+77
# T 162
# X 163
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 664
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# X 859
# ---
# Q 292+167
# T 1053
# X 1054
# ---
# Q 795+038
# T 1427
# X 1431
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 235
# ---
# 검증 정확도 29.820%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 11 |  반복 121 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 11 |  반복 161 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 11 |  반복 181 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 11 |  반복 221 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 11 |  반복 261 / 351 | 시간 7[s] | 손실 0.46
# | 에폭 11 |  반복 281 / 351 | 시간 7[s] | 손실 0.46
# | 에폭 11 |  반복 301 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 11 |  반복 321 / 351 | 시간 8[s] | 손실 0.45
# | 에폭 11 |  반복 341 / 351 | 시간 9[s] | 손실 0.45
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# X 859
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1426
# ---
# Q  838+62
# T 864
# X 866
# ---
# Q  39+341
# T 236
# X 238
# ---
# 검증 정확도 28.480%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 12 |  반복 181 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 12 |  반복 201 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 12 |  반복 221 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 12 |  반복 241 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 12 |  반복 261 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 12 |  반복 281 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 12 |  반복 301 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 12 |  반복 321 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 12 |  반복 341 / 351 | 시간 8[s] | 손실 0.43
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 667
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# X 1051
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# X 862
# ---
# Q  39+341
# T 236
# X 237
# ---
# 검증 정확도 36.640%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 0.44
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 13 |  반복 161 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 13 |  반복 181 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 13 |  반복 201 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 13 |  반복 221 / 351 | 시간 5[s] | 손실 0.43
# | 에폭 13 |  반복 241 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 13 |  반복 261 / 351 | 시간 6[s] | 손실 0.41
# | 에폭 13 |  반복 281 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 13 |  반복 301 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 13 |  반복 321 / 351 | 시간 8[s] | 손실 0.43
# | 에폭 13 |  반복 341 / 351 | 시간 8[s] | 손실 0.40
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 424
# ---
# Q 752+006
# T 857
# X 856
# ---
# Q 292+167
# T 1053
# X 1054
# ---
# Q 795+038
# T 1427
# X 1429
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 39.420%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.41
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.40
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.40
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 14 |  반복 121 / 351 | 시간 2[s] | 손실 0.39
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 0.39
# | 에폭 14 |  반복 161 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 14 |  반복 181 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 14 |  반복 201 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 14 |  반복 221 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 14 |  반복 241 / 351 | 시간 5[s] | 손실 0.39
# | 에폭 14 |  반복 261 / 351 | 시간 6[s] | 손실 0.40
# | 에폭 14 |  반복 281 / 351 | 시간 6[s] | 손실 0.41
# | 에폭 14 |  반복 301 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 14 |  반복 321 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 14 |  반복 341 / 351 | 시간 8[s] | 손실 0.39
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1137
# ---
# Q  48+285
# T 666
# X 667
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1426
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 235
# ---
# 검증 정확도 36.680%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.39
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.39
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.38
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 15 |  반복 121 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 15 |  반복 141 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 15 |  반복 161 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 15 |  반복 181 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 15 |  반복 201 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 15 |  반복 221 / 351 | 시간 5[s] | 손실 0.39
# | 에폭 15 |  반복 241 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 15 |  반복 261 / 351 | 시간 6[s] | 손실 0.37
# | 에폭 15 |  반복 281 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 15 |  반복 301 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 15 |  반복 321 / 351 | 시간 8[s] | 손실 0.39
# | 에폭 15 |  반복 341 / 351 | 시간 8[s] | 손실 0.37
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1137
# ---
# Q  48+285
# T 666
# X 667
# ---
# Q   551+8
# T 163
# X 164
# ---
# Q  55+763
# T 422
# X 420
# ---
# Q 752+006
# T 857
# X 856
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1431
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 237
# ---
# 검증 정확도 41.100%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.37
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 16 |  반복 141 / 351 | 시간 3[s] | 손실 0.36
# | 에폭 16 |  반복 161 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 16 |  반복 181 / 351 | 시간 4[s] | 손실 0.36
# | 에폭 16 |  반복 201 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 16 |  반복 221 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 16 |  반복 241 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 16 |  반복 261 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 16 |  반복 281 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 16 |  반복 301 / 351 | 시간 7[s] | 손실 0.35
# | 에폭 16 |  반복 321 / 351 | 시간 7[s] | 손실 0.35
# | 에폭 16 |  반복 341 / 351 | 시간 8[s] | 손실 0.37
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1142
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# X 1054
# ---
# Q 795+038
# T 1427
# X 1430
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 237
# ---
# 검증 정확도 42.700%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 17 |  반복 41 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 17 |  반복 81 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 17 |  반복 121 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 17 |  반복 141 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 17 |  반복 161 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 17 |  반복 181 / 351 | 시간 4[s] | 손실 0.35
# | 에폭 17 |  반복 201 / 351 | 시간 4[s] | 손실 0.35
# | 에폭 17 |  반복 221 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 17 |  반복 241 / 351 | 시간 5[s] | 손실 0.35
# | 에폭 17 |  반복 261 / 351 | 시간 6[s] | 손실 0.36
# | 에폭 17 |  반복 281 / 351 | 시간 6[s] | 손실 0.37
# | 에폭 17 |  반복 301 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 17 |  반복 321 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 17 |  반복 341 / 351 | 시간 8[s] | 손실 0.36
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1138
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 856
# ---
# Q 292+167
# T 1053
# X 1051
# ---
# Q 795+038
# T 1427
# X 1429
# ---
# Q  838+62
# T 864
# X 865
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 42.880%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 81 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 18 |  반복 121 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 18 |  반복 141 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 18 |  반복 161 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 18 |  반복 181 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 18 |  반복 221 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 18 |  반복 261 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 18 |  반복 281 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 18 |  반복 301 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 18 |  반복 321 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 18 |  반복 341 / 351 | 시간 8[s] | 손실 0.35
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1138
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 856
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1425
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 237
# ---
# 검증 정확도 40.640%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 19 |  반복 121 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 19 |  반복 141 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 19 |  반복 161 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 19 |  반복 181 / 351 | 시간 4[s] | 손실 0.30
# | 에폭 19 |  반복 201 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 19 |  반복 221 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 19 |  반복 241 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 19 |  반복 261 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 19 |  반복 281 / 351 | 시간 7[s] | 손실 0.32
# | 에폭 19 |  반복 301 / 351 | 시간 7[s] | 손실 0.32
# | 에폭 19 |  반복 321 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 19 |  반복 341 / 351 | 시간 8[s] | 손실 0.33
# Q   58+77
# T 162
# X 161
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1430
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 238
# ---
# 검증 정확도 47.540%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.33
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.33
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.31
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.31
# | 에폭 20 |  반복 121 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 20 |  반복 161 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 20 |  반복 201 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 20 |  반복 221 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 20 |  반복 241 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 20 |  반복 261 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 20 |  반복 281 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 20 |  반복 301 / 351 | 시간 7[s] | 손실 0.34
# | 에폭 20 |  반복 321 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 20 |  반복 341 / 351 | 시간 8[s] | 손실 0.32
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 665
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# X 859
# ---
# Q 292+167
# T 1053
# X 1051
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# X 862
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 49.960%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.30
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.30
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 21 |  반복 121 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 0.30
# | 에폭 21 |  반복 161 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 21 |  반복 181 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 21 |  반복 201 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 21 |  반복 221 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 21 |  반복 241 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 21 |  반복 261 / 351 | 시간 6[s] | 손실 0.29
# | 에폭 21 |  반복 281 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 21 |  반복 301 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 21 |  반복 321 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 21 |  반복 341 / 351 | 시간 8[s] | 손실 0.29
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# X 859
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 51.040%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.29
# | 에폭 22 |  반복 81 / 351 | 시간 1[s] | 손실 0.29
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.28
# | 에폭 22 |  반복 121 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 22 |  반복 161 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 22 |  반복 181 / 351 | 시간 4[s] | 손실 0.30
# | 에폭 22 |  반복 201 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 22 |  반복 221 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 22 |  반복 241 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 22 |  반복 261 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 22 |  반복 281 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 22 |  반복 301 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 22 |  반복 321 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 22 |  반복 341 / 351 | 시간 8[s] | 손실 0.31
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 856
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1430
# ---
# Q  838+62
# T 864
# X 865
# ---
# Q  39+341
# T 236
# X 238
# ---
# 검증 정확도 47.740%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 23 |  반복 81 / 351 | 시간 1[s] | 손실 0.29
# | 에폭 23 |  반복 101 / 351 | 시간 2[s] | 손실 0.27
# | 에폭 23 |  반복 121 / 351 | 시간 2[s] | 손실 0.28
# | 에폭 23 |  반복 141 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 23 |  반복 161 / 351 | 시간 3[s] | 손실 0.30
# | 에폭 23 |  반복 181 / 351 | 시간 4[s] | 손실 0.30
# | 에폭 23 |  반복 201 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 23 |  반복 221 / 351 | 시간 5[s] | 손실 0.29
# | 에폭 23 |  반복 241 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 23 |  반복 261 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 23 |  반복 281 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 23 |  반복 301 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 23 |  반복 321 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 23 |  반복 341 / 351 | 시간 8[s] | 손실 0.28
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1142
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1429
# ---
# Q  838+62
# T 864
# X 866
# ---
# Q  39+341
# T 236
# X 238
# ---
# 검증 정확도 45.180%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.29
# | 에폭 24 |  반복 81 / 351 | 시간 2[s] | 손실 0.30
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 24 |  반복 121 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 24 |  반복 141 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 24 |  반복 161 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 24 |  반복 181 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 24 |  반복 201 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 24 |  반복 221 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 24 |  반복 241 / 351 | 시간 5[s] | 손실 0.29
# | 에폭 24 |  반복 261 / 351 | 시간 6[s] | 손실 0.29
# | 에폭 24 |  반복 281 / 351 | 시간 6[s] | 손실 0.29
# | 에폭 24 |  반복 301 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 24 |  반복 321 / 351 | 시간 7[s] | 손실 0.27
# | 에폭 24 |  반복 341 / 351 | 시간 8[s] | 손실 0.29
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# X 1054
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 237
# ---
# 검증 정확도 51.800%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 25 |  반복 41 / 351 | 시간 0[s] | 손실 0.28
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.26
# | 에폭 25 |  반복 81 / 351 | 시간 1[s] | 손실 0.26
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 0.27
# | 에폭 25 |  반복 121 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 25 |  반복 161 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 25 |  반복 201 / 351 | 시간 4[s] | 손실 0.27
# | 에폭 25 |  반복 221 / 351 | 시간 5[s] | 손실 0.29
# | 에폭 25 |  반복 241 / 351 | 시간 5[s] | 손실 0.27
# | 에폭 25 |  반복 261 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 25 |  반복 281 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 25 |  반복 301 / 351 | 시간 7[s] | 손실 0.27
# | 에폭 25 |  반복 321 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 25 |  반복 341 / 351 | 시간 8[s] | 손실 0.28
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 856
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1426
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 54.060%

# %%
plt.plot(range(len(acc_list)), acc_list, 'o-', label='baseline')
plt.plot(range(len(racc_list)), racc_list, 'rD-', label='reverse')
plt.ylim([0,1])
plt.legend()
plt.show()

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 모델 / 옵티마이저 / 트레이너 생성
model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

pracc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
    acc = float(correct_num) / len(x_test)
    pracc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.57
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.48
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 2.20
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.99
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.89
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.82
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.82
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.80
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 3[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 7[s] | 손실 1.73
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.73
# Q   58+77
# T 162
# X 100
# ---
# Q 461+579
# T 1139
# X 1013
# ---
# Q  48+285
# T 666
# X 102
# ---
# Q   551+8
# T 163
# X 100
# ---
# Q  55+763
# T 422
# X 1023
# ---
# Q 752+006
# T 857
# X 1023
# ---
# Q 292+167
# T 1053
# X 1023
# ---
# Q 795+038
# T 1427
# X 1111
# ---
# Q  838+62
# T 864
# X 102
# ---
# Q  39+341
# T 236
# X 102
# ---
# 검증 정확도 0.280%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.71
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.69
# | 에폭 2 |  반복 141 / 351 | 시간 3[s] | 손실 1.68
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.67
# | 에폭 2 |  반복 181 / 351 | 시간 4[s] | 손실 1.67
# | 에폭 2 |  반복 201 / 351 | 시간 4[s] | 손실 1.65
# | 에폭 2 |  반복 221 / 351 | 시간 5[s] | 손실 1.65
# | 에폭 2 |  반복 241 / 351 | 시간 5[s] | 손실 1.65
# | 에폭 2 |  반복 261 / 351 | 시간 6[s] | 손실 1.63
# | 에폭 2 |  반복 281 / 351 | 시간 6[s] | 손실 1.62
# | 에폭 2 |  반복 301 / 351 | 시간 6[s] | 손실 1.61
# | 에폭 2 |  반복 321 / 351 | 시간 7[s] | 손실 1.61
# | 에폭 2 |  반복 341 / 351 | 시간 7[s] | 손실 1.60
# Q   58+77
# T 162
# X 100
# ---
# Q 461+579
# T 1139
# X 1200
# ---
# Q  48+285
# T 666
# X 690
# ---
# Q   551+8
# T 163
# X 100
# ---
# Q  55+763
# T 422
# X 690
# ---
# Q 752+006
# T 857
# X 999
# ---
# Q 292+167
# T 1053
# X 1029
# ---
# Q 795+038
# T 1427
# X 1240
# ---
# Q  838+62
# T 864
# X 792
# ---
# Q  39+341
# T 236
# X 290
# ---
# 검증 정확도 0.400%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.58
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.59
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.58
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.56
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.55
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.53
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.51
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.50
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.49
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.47
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 1.46
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.43
# | 에폭 3 |  반복 241 / 351 | 시간 5[s] | 손실 1.42
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 1.41
# | 에폭 3 |  반복 281 / 351 | 시간 6[s] | 손실 1.39
# | 에폭 3 |  반복 301 / 351 | 시간 7[s] | 손실 1.37
# | 에폭 3 |  반복 321 / 351 | 시간 7[s] | 손실 1.36
# | 에폭 3 |  반복 341 / 351 | 시간 8[s] | 손실 1.35
# Q   58+77
# T 162
# X 154
# ---
# Q 461+579
# T 1139
# X 1033
# ---
# Q  48+285
# T 666
# X 644
# ---
# Q   551+8
# T 163
# X 161
# ---
# Q  55+763
# T 422
# X 433
# ---
# Q 752+006
# T 857
# X 818
# ---
# Q 292+167
# T 1053
# X 1018
# ---
# Q 795+038
# T 1427
# X 1344
# ---
# Q  838+62
# T 864
# X 834
# ---
# Q  39+341
# T 236
# X 211
# ---
# 검증 정확도 1.600%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.32
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.32
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 1.28
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 4 |  반복 121 / 351 | 시간 3[s] | 손실 1.25
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 1.24
# | 에폭 4 |  반복 161 / 351 | 시간 4[s] | 손실 1.22
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 1.21
# | 에폭 4 |  반복 201 / 351 | 시간 5[s] | 손실 1.20
# | 에폭 4 |  반복 221 / 351 | 시간 5[s] | 손실 1.20
# | 에폭 4 |  반복 241 / 351 | 시간 6[s] | 손실 1.17
# | 에폭 4 |  반복 261 / 351 | 시간 6[s] | 손실 1.16
# | 에폭 4 |  반복 281 / 351 | 시간 7[s] | 손실 1.14
# | 에폭 4 |  반복 301 / 351 | 시간 7[s] | 손실 1.12
# | 에폭 4 |  반복 321 / 351 | 시간 8[s] | 손실 1.11
# | 에폭 4 |  반복 341 / 351 | 시간 9[s] | 손실 1.10
# Q   58+77
# T 162
# X 158
# ---
# Q 461+579
# T 1139
# X 1123
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# X 165
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 777
# ---
# Q 292+167
# T 1053
# X 1023
# ---
# Q 795+038
# T 1427
# X 1388
# ---
# Q  838+62
# T 864
# X 887
# ---
# Q  39+341
# T 236
# X 223
# ---
# 검증 정확도 5.140%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.08
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.07
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 1.04
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 1.01
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 5 |  반복 161 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 5 |  반복 181 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 5 |  반복 201 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 5 |  반복 221 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 5 |  반복 241 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 5 |  반복 261 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 5 |  반복 281 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 5 |  반복 301 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 5 |  반복 321 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 5 |  반복 341 / 351 | 시간 9[s] | 손실 0.87
# Q   58+77
# T 162
# X 160
# ---
# Q 461+579
# T 1139
# X 1135
# ---
# Q  48+285
# T 666
# X 668
# ---
# Q   551+8
# T 163
# X 169
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 861
# ---
# Q 292+167
# T 1053
# X 1045
# ---
# Q 795+038
# T 1427
# X 1324
# ---
# Q  838+62
# T 864
# X 861
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 9.380%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 6 |  반복 141 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 6 |  반복 161 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 6 |  반복 201 / 351 | 시간 5[s] | 손실 0.76
# | 에폭 6 |  반복 221 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 6 |  반복 241 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 6 |  반복 261 / 351 | 시간 7[s] | 손실 0.74
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 6 |  반복 301 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 6 |  반복 341 / 351 | 시간 9[s] | 손실 0.71
# Q   58+77
# T 162
# X 163
# ---
# Q 461+579
# T 1139
# X 1138
# ---
# Q  48+285
# T 666
# X 668
# ---
# Q   551+8
# T 163
# X 166
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# X 1048
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# X 873
# ---
# Q  39+341
# T 236
# X 239
# ---
# 검증 정확도 15.040%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.67
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 0.66
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 0.66
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 0.65
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 0.65
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 0.64
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 0.63
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 0.61
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 0.61
# | 에폭 7 |  반복 221 / 351 | 시간 6[s] | 손실 0.60
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 7 |  반복 261 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 7 |  반복 301 / 351 | 시간 8[s] | 손실 0.55
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 0.54
# | 에폭 7 |  반복 341 / 351 | 시간 9[s] | 손실 0.53
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 665
# ---
# Q   551+8
# T 163
# X 156
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 858
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# X 235
# ---
# 검증 정확도 39.100%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.49
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 8 |  반복 161 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 8 |  반복 181 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 8 |  반복 201 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 8 |  반복 221 / 351 | 시간 5[s] | 손실 0.40
# | 에폭 8 |  반복 241 / 351 | 시간 6[s] | 손실 0.39
# | 에폭 8 |  반복 261 / 351 | 시간 6[s] | 손실 0.37
# | 에폭 8 |  반복 281 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 8 |  반복 301 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 8 |  반복 321 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 8 |  반복 341 / 351 | 시간 9[s] | 손실 0.34
# Q   58+77
# T 162
# X 161
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# X 155
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1438
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 65.060%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 0.27
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 0.27
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 0.26
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.25
# | 에폭 9 |  반복 221 / 351 | 시간 6[s] | 손실 0.25
# | 에폭 9 |  반복 241 / 351 | 시간 6[s] | 손실 0.24
# | 에폭 9 |  반복 261 / 351 | 시간 7[s] | 손실 0.24
# | 에폭 9 |  반복 281 / 351 | 시간 7[s] | 손실 0.23
# | 에폭 9 |  반복 301 / 351 | 시간 8[s] | 손실 0.22
# | 에폭 9 |  반복 321 / 351 | 시간 8[s] | 손실 0.22
# | 에폭 9 |  반복 341 / 351 | 시간 9[s] | 손실 0.21
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1140
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 83.280%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.22
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.20
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.18
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.17
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 0.18
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.17
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.17
# | 에폭 10 |  반복 221 / 351 | 시간 6[s] | 손실 0.16
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 0.15
# | 에폭 10 |  반복 261 / 351 | 시간 7[s] | 손실 0.15
# | 에폭 10 |  반복 281 / 351 | 시간 7[s] | 손실 0.15
# | 에폭 10 |  반복 301 / 351 | 시간 8[s] | 손실 0.15
# | 에폭 10 |  반복 321 / 351 | 시간 8[s] | 손실 0.14
# | 에폭 10 |  반복 341 / 351 | 시간 9[s] | 손실 0.14
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# X 656
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 88.400%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.13
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.13
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.13
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.12
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.12
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 0.12
# | 에폭 11 |  반복 121 / 351 | 시간 3[s] | 손실 0.11
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 0.12
# | 에폭 11 |  반복 161 / 351 | 시간 4[s] | 손실 0.11
# | 에폭 11 |  반복 181 / 351 | 시간 4[s] | 손실 0.11
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 0.12
# | 에폭 11 |  반복 221 / 351 | 시간 6[s] | 손실 0.11
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 0.11
# | 에폭 11 |  반복 261 / 351 | 시간 7[s] | 손실 0.10
# | 에폭 11 |  반복 281 / 351 | 시간 7[s] | 손실 0.10
# | 에폭 11 |  반복 301 / 351 | 시간 8[s] | 손실 0.10
# | 에폭 11 |  반복 321 / 351 | 시간 8[s] | 손실 0.09
# | 에폭 11 |  반복 341 / 351 | 시간 9[s] | 손실 0.09
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 90.940%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.09
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.09
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.09
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.09
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.09
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.08
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 0.08
# | 에폭 12 |  반복 181 / 351 | 시간 4[s] | 손실 0.08
# | 에폭 12 |  반복 201 / 351 | 시간 5[s] | 손실 0.08
# | 에폭 12 |  반복 221 / 351 | 시간 6[s] | 손실 0.09
# | 에폭 12 |  반복 241 / 351 | 시간 6[s] | 손실 0.09
# | 에폭 12 |  반복 261 / 351 | 시간 7[s] | 손실 0.09
# | 에폭 12 |  반복 281 / 351 | 시간 7[s] | 손실 0.08
# | 에폭 12 |  반복 301 / 351 | 시간 8[s] | 손실 0.08
# | 에폭 12 |  반복 321 / 351 | 시간 8[s] | 손실 0.07
# | 에폭 12 |  반복 341 / 351 | 시간 9[s] | 손실 0.08
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 92.220%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.07
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.07
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.06
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 0.06
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.07
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 0.06
# | 에폭 13 |  반복 161 / 351 | 시간 4[s] | 손실 0.06
# | 에폭 13 |  반복 181 / 351 | 시간 4[s] | 손실 0.06
# | 에폭 13 |  반복 201 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 13 |  반복 221 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 13 |  반복 241 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 13 |  반복 261 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 13 |  반복 281 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 13 |  반복 301 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 13 |  반복 321 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 13 |  반복 341 / 351 | 시간 9[s] | 손실 0.06
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 94.400%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 14 |  반복 121 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 14 |  반복 161 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 14 |  반복 181 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 14 |  반복 201 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 14 |  반복 221 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 14 |  반복 241 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 14 |  반복 261 / 351 | 시간 7[s] | 손실 0.07
# | 에폭 14 |  반복 281 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 14 |  반복 301 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 14 |  반복 321 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 14 |  반복 341 / 351 | 시간 9[s] | 손실 0.05
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 94.640%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 15 |  반복 121 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 15 |  반복 141 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 15 |  반복 161 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 15 |  반복 181 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 15 |  반복 201 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 15 |  반복 221 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 15 |  반복 241 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 15 |  반복 261 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 15 |  반복 281 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 15 |  반복 301 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 15 |  반복 321 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 15 |  반복 341 / 351 | 시간 9[s] | 손실 0.05
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 96.660%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 16 |  반복 141 / 351 | 시간 3[s] | 손실 0.07
# | 에폭 16 |  반복 161 / 351 | 시간 4[s] | 손실 0.07
# | 에폭 16 |  반복 181 / 351 | 시간 4[s] | 손실 0.06
# | 에폭 16 |  반복 201 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 16 |  반복 221 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 16 |  반복 241 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 16 |  반복 261 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 16 |  반복 281 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 16 |  반복 301 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 16 |  반복 321 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 16 |  반복 341 / 351 | 시간 9[s] | 손실 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 97.000%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 17 |  반복 121 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 17 |  반복 141 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 17 |  반복 161 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 17 |  반복 181 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 17 |  반복 201 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 17 |  반복 221 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 17 |  반복 241 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 17 |  반복 261 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 17 |  반복 281 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 17 |  반복 301 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 17 |  반복 321 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 17 |  반복 341 / 351 | 시간 9[s] | 손실 0.05
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 90.160%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 18 |  반복 81 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 18 |  반복 121 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 18 |  반복 141 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 18 |  반복 161 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 18 |  반복 181 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 18 |  반복 201 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 18 |  반복 221 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 18 |  반복 241 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 18 |  반복 261 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 18 |  반복 281 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 18 |  반복 301 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 18 |  반복 321 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 18 |  반복 341 / 351 | 시간 9[s] | 손실 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 96.000%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 19 |  반복 121 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 19 |  반복 141 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 19 |  반복 161 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 19 |  반복 181 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 19 |  반복 201 / 351 | 시간 5[s] | 손실 0.02
# | 에폭 19 |  반복 221 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 19 |  반복 241 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 19 |  반복 261 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 19 |  반복 281 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 19 |  반복 301 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 19 |  반복 321 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 19 |  반복 341 / 351 | 시간 9[s] | 손실 0.02
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 98.300%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 20 |  반복 121 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 20 |  반복 161 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 20 |  반복 201 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 20 |  반복 221 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 20 |  반복 241 / 351 | 시간 6[s] | 손실 0.09
# | 에폭 20 |  반복 261 / 351 | 시간 7[s] | 손실 0.08
# | 에폭 20 |  반복 281 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 20 |  반복 301 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 20 |  반복 321 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 20 |  반복 341 / 351 | 시간 9[s] | 손실 0.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 94.540%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 21 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 21 |  반복 161 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 21 |  반복 181 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 21 |  반복 201 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 21 |  반복 221 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 21 |  반복 241 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 21 |  반복 261 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 21 |  반복 281 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 21 |  반복 301 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 21 |  반복 321 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 21 |  반복 341 / 351 | 시간 9[s] | 손실 0.01
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 98.820%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 22 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 22 |  반복 161 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 22 |  반복 181 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 22 |  반복 201 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 22 |  반복 221 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 22 |  반복 241 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 22 |  반복 261 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 22 |  반복 281 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 22 |  반복 301 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 22 |  반복 321 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 22 |  반복 341 / 351 | 시간 9[s] | 손실 0.02
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# X 1437
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 97.360%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 23 |  반복 101 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 23 |  반복 121 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 23 |  반복 141 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 23 |  반복 161 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 23 |  반복 181 / 351 | 시간 4[s] | 손실 0.07
# | 에폭 23 |  반복 201 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 23 |  반복 221 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 23 |  반복 241 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 23 |  반복 261 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 23 |  반복 281 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 23 |  반복 301 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 23 |  반복 321 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 23 |  반복 341 / 351 | 시간 9[s] | 손실 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 97.340%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 24 |  반복 81 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 24 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 24 |  반복 141 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 24 |  반복 161 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 24 |  반복 181 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 24 |  반복 201 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 24 |  반복 221 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 24 |  반복 241 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 24 |  반복 261 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 24 |  반복 281 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 24 |  반복 301 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 24 |  반복 321 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 24 |  반복 341 / 351 | 시간 9[s] | 손실 0.01
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 98.860%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 25 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 25 |  반복 161 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 25 |  반복 201 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 25 |  반복 221 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 25 |  반복 241 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 25 |  반복 261 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 25 |  반복 281 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 25 |  반복 301 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 25 |  반복 321 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 25 |  반복 341 / 351 | 시간 9[s] | 손실 0.07
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# 검증 정확도 93.160%

# %%
plt.plot(range(len(acc_list)), acc_list, 'o-', label='baseline')
plt.plot(range(len(racc_list)), racc_list, 'rD-', label='reverse')
plt.plot(range(len(pracc_list)), pracc_list, 'gv-', label='Peeky+reverse')
plt.ylim([0,1])
plt.legend(loc='upper left')
plt.show()
